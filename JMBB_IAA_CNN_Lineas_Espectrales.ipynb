# %% [markdown]
# # Generation of training and testing data from models
# ****
# - Data source: Dr. Michel Curé and Catalina Arcos, IFA UV
# - Each model is stored in a file with a name like: "t4000g20v10.dat", where
#  - t is the effective temperature: 4000 [K]
#  - g is 10 times the logarithm of the gravity in [cm/seg^2]: 20/10 = 2.0
#  - v_rot is the rotational velocity in [km/seg]: 10
#
# - For this analysis we will consider:
#  - v_rot >= 100
#  - t_eff >= 15000
#  - wavelength range [4460, 4480]
#
# - Note that the y axis is the normalized flux

# %% [markdown]
# ## Needed libraries

# %%
import glob
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import shutil

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Functions

# %%
def string2params(string, show=True):
    s1 = string.partition("g")
    t = s1[0][1:]
    s2 = s1[2].partition("v")
    g = s2[0]
    v = s2[-1]
    if show:
        print(s1)
        print("t:",t)
        print(s2)
        print("g: ",float(g)/10)
        print("v:", v)
    return float(t), float(g)/10, float(v)

# %% [markdown]
# ## Files list

# %%
files = glob.glob('filtered_wv_models/*')
m = len(files)
print("Number of files in models", m)
print("5 first files: \n", files[0:5])
# Out:
# Number of files in models 5425
# 5 first files:
#  ['filtered_wv_models\\f_t15000g20v100.dat', 'filtered_wv_models\\f_t15000g20v110.dat', 'filtered_wv_models\\f_t15000g20v120.dat', 'filtered_wv_models\\f_t15000g20v130.dat', 'filtered_wv_models\\f_t15000g20v140.dat']

# %% [markdown]
# ## Building X an y matrices
# *****

# %%
#print("--> X has dimension", m, " x 201")
#print("--> y has diemsnion", m, " x 3")

y = np.zeros((m,3))
df = pd.read_csv(files[0], sep=" ", header=None)
x_points = df[0].values
n_points, n_columns = df.shape
#display(df[1].values.shape)
#print("Num. of points in x axis: ", n_points)

df_line = pd.read_csv("filtered_wv_models\\f_t15000g20v140.dat",
                      sep=" ", header=None)
#plot
plt.figure(figsize=(8,4))
plt.plot(df_line[0].values, df_line[1].values)
plt.xlabel("Longitud de onda [A]")
plt.ylabel("Flujo normalizado")
plt.grid()
plt.show()

# %%
# X matrix contains the spectral lines
X = np.zeros((m,n_points))
# y matrix contains the labels of each spectral line
y = np.zeros((m,3))
for i,name in enumerate(files):
    file_name = name.split("\\")[-1].split(".")[0]
    #print(file_name)
    
    df = pd.read_csv(name, sep=" ", header=None)
    #print(file_name.split("_")[1])
    t,g,v = string2params(file_name.split("_")[1])
    X[i,:] = df[1].values
    y[i] = t,g,v
    #print("----")
# Out:
# ('t15000', 'g', '20v100')
# t: 15000
# ('20', 'v', '100')
# g:  2.0
# v: 100
# ('t15000', 'g', '20v110')
# t: 15000
# ('20', 'v', '110')
# g:  2.0
# v: 110
# ('t15000', 'g', '20v120')
# t: 15000
# ('20', 'v', '120')
# g:  2.0
# v: 120
# ('t15000', 'g', '20v130')
# t: 15000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# ('t15000', 'g', '20v140')
# t: 15000
# ('20', 'v', '140')
# g:  2.0
# v: 140
# ('t15000', 'g', '20v150')
# t: 15000
# ('20', 'v', '150')
# g:  2.0
# v: 150
# ('t15000', 'g', '20v160')
# t: 15000
# ('20', 'v', '160')
# g:  2.0
# v: 160
# ('t15000', 'g', '20v170')
# t: 15000
# ('20', 'v', '170')
# g:  2.0
# v: 170
# ('t15000', 'g', '20v180')
# t: 15000
# ('20', 'v', '180')
# g:  2.0
# v: 180
# ('t15000', 'g', '20v190')
# t: 15000
# ('20', 'v', '190')
# g:  2.0
# v: 190
# ('t15000', 'g', '20v200')
# t: 15000
# ('20', 'v', '200')
# g:  2.0
# v: 200
# ('t15000', 'g', '20v210')
# t: 15000
# ('20', 'v', '210')
# g:  2.0
# v: 210
# ('t15000', 'g', '20v220')
# t: 15000
# ('20', 'v', '220')
# g:  2.0
# v: 220
# ('t15000', 'g', '20v230')
# t: 15000
# ('20', 'v', '230')
# g:  2.0
# v: 230
# ('t15000', 'g', '20v240')
# t: 15000
# ('20', 'v', '240')
# g:  2.0
# v: 240
# ('t15000', 'g', '20v250')
# t: 15000
# ('20', 'v', '250')
# g:  2.0
# v: 250
# ('t15000', 'g', '20v260')
# t: 15000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# ('t15000', 'g', '20v270')
# t: 15000
# ('20', 'v', '270')
# g:  2.0
# v: 270
# ('t15000', 'g', '20v280')
# t: 15000
# ('20', 'v', '280')
# g:  2.0
# v: 280
# ('t15000', 'g', '20v290')
# t: 15000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# ('t15000', 'g', '20v300')
# t: 15000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# ('t15000', 'g', '20v310')
# t: 15000
# ('20', 'v', '310')
# g:  2.0
# v: 310
# ('t15000', 'g', '20v320')
# t: 15000
# ('20', 'v', '320')
# g:  2.0
# v: 320
# ('t15000', 'g', '20v330')
# t: 15000
# ('20', 'v', '330')
# g:  2.0
# v: 330
# ('t15000', 'g', '20v340')
# t: 15000
# ('20', 'v', '340')
# g:  2.0
# v: 340
# ('t15000', 'g', '20v350')
# t: 15000
# ('20', 'v', '350')
# g:  2.0
# v: 350
# ('t15000', 'g', '20v360')
# t: 15000
# ('20', 'v', '360')
# g:  2.0
# v: 360
# ('t15000', 'g', '20v370')
# t: 15000
# ('20', 'v', '370')
# g:  2.0
# v: 370
# ('t15000', 'g', '20v380')
# t: 15000
# ('20', 'v', '380')
# g:  2.0
# v: 380
# ('t15000', 'g', '20v390')
# t: 15000
# ('20', 'v', '390')
# g:  2.0
# v: 390
# ('t15000', 'g', '20v400')
# t: 15000
# ('20', 'v', '400')
# g:  2.0
# v: 400
# ('t15000', 'g', '25v100')
# t: 15000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# ('t15000', 'g', '25v110')
# t: 15000
# ('25', 'v', '110')
# g:  2.5
# v: 110
# ('t15000', 'g', '25v120')
# t: 15000
# ('25', 'v', '120')
# g:  2.5
# v: 120
# ('t15000', 'g', '25v130')
# t: 15000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# ('t15000', 'g', '25v140')
# t: 15000
# ('25', 'v', '140')
# g:  2.5
# v: 140
# ('t15000', 'g', '25v150')
# t: 15000
# ('25', 'v', '150')
# g:  2.5
# v: 150
# ('t15000', 'g', '25v160')
# t: 15000
# ('25', 'v', '160')
# g:  2.5
# v: 160
# ('t15000', 'g', '25v170')
# t: 15000
# ('25', 'v', '170')
# g:  2.5
# v: 170
# ('t15000', 'g', '25v180')
# t: 15000
# ('25', 'v', '180')
# g:  2.5
# v: 180
# ('t15000', 'g', '25v190')
# t: 15000
# ('25', 'v', '190')
# g:  2.5
# v: 190
# ('t15000', 'g', '25v200')
# t: 15000
# ('25', 'v', '200')
# g:  2.5
# v: 200
# ('t15000', 'g', '25v210')
# t: 15000
# ('25', 'v', '210')
# g:  2.5
# v: 210
# ('t15000', 'g', '25v220')
# t: 15000
# ('25', 'v', '220')
# g:  2.5
# v: 220
# ('t15000', 'g', '25v230')
# t: 15000
# ('25', 'v', '230')
# g:  2.5
# v: 230
# ('t15000', 'g', '25v240')
# t: 15000
# ('25', 'v', '240')
# g:  2.5
# v: 240
# ('t15000', 'g', '25v250')
# t: 15000
# ('25', 'v', '250')
# g:  2.5
# v: 250
# ('t15000', 'g', '25v260')
# t: 15000
# ('25', 'v', '260')
# g:  2.5
# v: 260
# ('t15000', 'g', '25v270')
# t: 15000
# ('25', 'v', '270')
# g:  2.5
# v: 270
# ('t15000', 'g', '25v280')
# t: 15000
# ('25', 'v', '280')
# g:  2.5
# v: 280
# ('t15000', 'g', '25v290')
# t: 15000
# ('25', 'v', '290')
# g:  2.5
# v: 290
# ('t15000', 'g', '25v300')
# t: 15000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# ('t15000', 'g', '25v310')
# t: 15000
# ('25', 'v', '310')
# g:  2.5
# v: 310
# ('t15000', 'g', '25v320')
# t: 15000
# ('25', 'v', '320')
# g:  2.5
# v: 320
# ('t15000', 'g', '25v330')
# t: 15000
# ('25', 'v', '330')
# g:  2.5
# v: 330
# ('t15000', 'g', '25v340')
# t: 15000
# ('25', 'v', '340')
# g:  2.5
# v: 340
# ('t15000', 'g', '25v350')
# t: 15000
# ('25', 'v', '350')
# g:  2.5
# v: 350
# ('t15000', 'g', '25v360')
# t: 15000
# ('25', 'v', '360')
# g:  2.5
# v: 360
# ('t15000', 'g', '25v370')
# t: 15000
# ('25', 'v', '370')
# g:  2.5
# v: 370
# ('t15000', 'g', '25v380')
# t: 15000
# ('25', 'v', '380')
# g:  2.5
# v: 380
# ('t15000', 'g', '25v390')
# t: 15000
# ('25', 'v', '390')
# g:  2.5
# v: 390
# ('t15000', 'g', '25v400')
# t: 15000
# ('25', 'v', '400')
# g:  2.5
# v: 400
# ('t15000', 'g', '30v100')
# t: 15000
# ('30', 'v', '100')
# g:  3.0
# v: 100
# ('t15000', 'g', '30v110')
# t: 15000
# ('30', 'v', '110')
# g:  3.0
# v: 110
# ('t15000', 'g', '30v120')
# t: 15000
# ('30', 'v', '120')
# g:  3.0
# v: 120
# ('t15000', 'g', '30v130')
# t: 15000
# ('30', 'v', '130')
# g:  3.0
# v: 130
# ('t15000', 'g', '30v140')
# t: 15000
# ('30', 'v', '140')
# g:  3.0
# v: 140
# ('t15000', 'g', '30v150')
# t: 15000
# ('30', 'v', '150')
# g:  3.0
# v: 150
# ('t15000', 'g', '30v160')
# t: 15000
# ('30', 'v', '160')
# g:  3.0
# v: 160
# ('t15000', 'g', '30v170')
# t: 15000
# ('30', 'v', '170')
# g:  3.0
# v: 170
# ('t15000', 'g', '30v180')
# t: 15000
# ('30', 'v', '180')
# g:  3.0
# v: 180
# ('t15000', 'g', '30v190')
# t: 15000
# ('30', 'v', '190')
# g:  3.0
# v: 190
# ('t15000', 'g', '30v200')
# t: 15000
# ('30', 'v', '200')
# g:  3.0
# v: 200
# ('t15000', 'g', '30v210')
# t: 15000
# ('30', 'v', '210')
# g:  3.0
# v: 210
# ('t15000', 'g', '30v220')
# t: 15000
# ('30', 'v', '220')
# g:  3.0
# v: 220
# ('t15000', 'g', '30v230')
# t: 15000
# ('30', 'v', '230')
# g:  3.0
# v: 230
# ('t15000', 'g', '30v240')
# t: 15000
# ('30', 'v', '240')
# g:  3.0
# v: 240
# ('t15000', 'g', '30v250')
# t: 15000
# ('30', 'v', '250')
# g:  3.0
# v: 250
# ('t15000', 'g', '30v260')
# t: 15000
# ('30', 'v', '260')
# g:  3.0
# v: 260
# ('t15000', 'g', '30v270')
# t: 15000
# ('30', 'v', '270')
# g:  3.0
# v: 270
# ('t15000', 'g', '30v280')
# t: 15000
# ('30', 'v', '280')
# g:  3.0
# v: 280
# ('t15000', 'g', '30v290')
# t: 15000
# ('30', 'v', '290')
# g:  3.0
# v: 290
# ('t15000', 'g', '30v300')
# t: 15000
# ('30', 'v', '300')
# g:  3.0
# v: 300
# ('t15000', 'g', '30v310')
# t: 15000
# ('30', 'v', '310')
# g:  3.0
# v: 310
# ('t15000', 'g', '30v320')
# t: 15000
# ('30', 'v', '320')
# g:  3.0
# v: 320
# ('t15000', 'g', '30v330')
# t: 15000
# ('30', 'v', '330')
# g:  3.0
# v: 330
# ('t15000', 'g', '30v340')
# t: 15000
# ('30', 'v', '340')
# g:  3.0
# v: 340
# ('t15000', 'g', '30v350')
# t: 15000
# ('30', 'v', '350')
# g:  3.0
# v: 350
# ('t15000', 'g', '30v360')
# t: 15000
# ('30', 'v', '360')
# g:  3.0
# v: 360
# ('t15000', 'g', '30v370')
# t: 15000
# ('30', 'v', '370')
# g:  3.0
# v: 370
# ('t15000', 'g', '30v380')
# t: 15000
# ('30', 'v', '380')
# g:  3.0
# v: 380
# ('t15000', 'g', '30v390')
# t: 15000
# ('30', 'v', '390')
# g:  3.0
# v: 390
# ('t15000', 'g', '30v400')
# t: 15000
# ('30', 'v', '400')
# g:  3.0
# v: 400
# ('t15000', 'g', '35v100')
# t: 15000
# ('35', 'v', '100')
# g:  3.5
# v: 100
# ('t15000', 'g', '35v110')
# t: 15000
# ('35', 'v', '110')
# g:  3.5
# v: 110
# ('t15000', 'g', '35v120')
# t: 15000
# ('35', 'v', '120')
# g:  3.5
# v: 120
# ('t15000', 'g', '35v130')
# t: 15000
# ('35', 'v', '130')
# g:  3.5
# v: 130
# ('t15000', 'g', '35v140')
# t: 15000
# ('35', 'v', '140')
# g:  3.5
# v: 140
# ('t15000', 'g', '35v150')
# t: 15000
# ('35', 'v', '150')
# g:  3.5
# v: 150
# ('t15000', 'g', '35v160')
# t: 15000
# ('35', 'v', '160')
# g:  3.5
# v: 160
# ('t15000', 'g', '35v170')
# t: 15000
# ('35', 'v', '170')
# g:  3.5
# v: 170
# ('t15000', 'g', '35v180')
# t: 15000
# ('35', 'v', '180')
# g:  3.5
# v: 180
# ('t15000', 'g', '35v190')
# t: 15000
# ('35', 'v', '190')
# g:  3.5
# v: 190
# ('t15000', 'g', '35v200')
# t: 15000
# ('35', 'v', '200')
# g:  3.5
# v: 200
# ('t15000', 'g', '35v210')
# t: 15000
# ('35', 'v', '210')
# g:  3.5
# v: 210
# ('t15000', 'g', '35v220')
# t: 15000
# ('35', 'v', '220')
# g:  3.5
# v: 220
# ('t15000', 'g', '35v230')
# t: 15000
# ('35', 'v', '230')
# g:  3.5
# v: 230
# ('t15000', 'g', '35v240')
# t: 15000
# ('35', 'v', '240')
# g:  3.5
# v: 240
# ('t15000', 'g', '35v250')
# t: 15000
# ('35', 'v', '250')
# g:  3.5
# v: 250
# ('t15000', 'g', '35v260')
# t: 15000
# ('35', 'v', '260')
# g:  3.5
# v: 260
# ('t15000', 'g', '35v270')
# t: 15000
# ('35', 'v', '270')
# g:  3.5
# v: 270
# ('t15000', 'g', '35v280')
# t: 15000
# ('35', 'v', '280')
# g:  3.5
# v: 280
# ('t15000', 'g', '35v290')
# t: 15000
# ('35', 'v', '290')
# g:  3.5
# v: 290
# ('t15000', 'g', '35v300')
# t: 15000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# ('t15000', 'g', '35v310')
# t: 15000
# ('35', 'v', '310')
# g:  3.5
# v: 310
# ('t15000', 'g', '35v320')
# t: 15000
# ('35', 'v', '320')
# g:  3.5
# v: 320
# ('t15000', 'g', '35v330')
# t: 15000
# ('35', 'v', '330')
# g:  3.5
# v: 330
# ('t15000', 'g', '35v340')
# t: 15000
# ('35', 'v', '340')
# g:  3.5
# v: 340
# ('t15000', 'g', '35v350')
# t: 15000
# ('35', 'v', '350')
# g:  3.5
# v: 350
# ('t15000', 'g', '35v360')
# t: 15000
# ('35', 'v', '360')
# g:  3.5
# v: 360
# ('t15000', 'g', '35v370')
# t: 15000
# ('35', 'v', '370')
# g:  3.5
# v: 370
# ('t15000', 'g', '35v380')
# t: 15000
# ('35', 'v', '380')
# g:  3.5
# v: 380
# ('t15000', 'g', '35v390')
# t: 15000
# ('35', 'v', '390')
# g:  3.5
# v: 390
# ('t15000', 'g', '35v400')
# t: 15000
# ('35', 'v', '400')
# g:  3.5
# v: 400
# ('t15000', 'g', '40v100')
# t: 15000
# ('40', 'v', '100')
# g:  4.0
# v: 100
# ('t15000', 'g', '40v110')
# t: 15000
# ('40', 'v', '110')
# g:  4.0
# v: 110
# ('t15000', 'g', '40v120')
# t: 15000
# ('40', 'v', '120')
# g:  4.0
# v: 120
# ('t15000', 'g', '40v130')
# t: 15000
# ('40', 'v', '130')
# g:  4.0
# v: 130
# ('t15000', 'g', '40v140')
# t: 15000
# ('40', 'v', '140')
# g:  4.0
# v: 140
# ('t15000', 'g', '40v150')
# t: 15000
# ('40', 'v', '150')
# g:  4.0
# v: 150
# ('t15000', 'g', '40v160')
# t: 15000
# ('40', 'v', '160')
# g:  4.0
# v: 160
# ('t15000', 'g', '40v170')
# t: 15000
# ('40', 'v', '170')
# g:  4.0
# v: 170
# ('t15000', 'g', '40v180')
# t: 15000
# ('40', 'v', '180')
# g:  4.0
# v: 180
# ('t15000', 'g', '40v190')
# t: 15000
# ('40', 'v', '190')
# g:  4.0
# v: 190
# ('t15000', 'g', '40v200')
# t: 15000
# ('40', 'v', '200')
# g:  4.0
# v: 200
# ('t15000', 'g', '40v210')
# t: 15000
# ('40', 'v', '210')
# g:  4.0
# v: 210
# ('t15000', 'g', '40v220')
# t: 15000
# ('40', 'v', '220')
# g:  4.0
# v: 220
# ('t15000', 'g', '40v230')
# t: 15000
# ('40', 'v', '230')
# g:  4.0
# v: 230
# ('t15000', 'g', '40v240')
# t: 15000
# ('40', 'v', '240')
# g:  4.0
# v: 240
# ('t15000', 'g', '40v250')
# t: 15000
# ('40', 'v', '250')
# g:  4.0
# v: 250
# ('t15000', 'g', '40v260')
# t: 15000
# ('40', 'v', '260')
# g:  4.0
# v: 260
# ('t15000', 'g', '40v270')
# t: 15000
# ('40', 'v', '270')
# g:  4.0
# v: 270
# ('t15000', 'g', '40v280')
# t: 15000
# ('40', 'v', '280')
# g:  4.0
# v: 280
# ('t15000', 'g', '40v290')
# t: 15000
# ('40', 'v', '290')
# g:  4.0
# v: 290
# ('t15000', 'g', '40v300')
# t: 15000
# ('40', 'v', '300')
# g:  4.0
# v: 300
# ('t15000', 'g', '40v310')
# t: 15000
# ('40', 'v', '310')
# g:  4.0
# v: 310
# ('t15000', 'g', '40v320')
# t: 15000
# ('40', 'v', '320')
# g:  4.0
# v: 320
# ('t15000', 'g', '40v330')
# t: 15000
# ('40', 'v', '330')
# g:  4.0
# v: 330
# ('t15000', 'g', '40v340')
# t: 15000
# ('40', 'v', '340')
# g:  4.0
# v: 340
# ('t15000', 'g', '40v350')
# t: 15000
# ('40', 'v', '350')
# g:  4.0
# v: 350
# ('t15000', 'g', '40v360')
# t: 15000
# ('40', 'v', '360')
# g:  4.0
# v: 360
# ('t15000', 'g', '40v370')
# t: 15000
# ('40', 'v', '370')
# g:  4.0
# v: 370
# ('t15000', 'g', '40v380')
# t: 15000
# ('40', 'v', '380')
# g:  4.0
# v: 380
# ('t15000', 'g', '40v390')
# t: 15000
# ('40', 'v', '390')
# g:  4.0
# v: 390
# ('t15000', 'g', '40v400')
# t: 15000
# ('40', 'v', '400')
# g:  4.0
# v: 400
# ('t15000', 'g', '45v100')
# t: 15000
# ('45', 'v', '100')
# g:  4.5
# v: 100
# ('t15000', 'g', '45v110')
# t: 15000
# ('45', 'v', '110')
# g:  4.5
# v: 110
# ('t15000', 'g', '45v120')
# t: 15000
# ('45', 'v', '120')
# g:  4.5
# v: 120
# ('t15000', 'g', '45v130')
# t: 15000
# ('45', 'v', '130')
# g:  4.5
# v: 130
# ('t15000', 'g', '45v140')
# t: 15000
# ('45', 'v', '140')
# g:  4.5
# v: 140
# ('t15000', 'g', '45v150')
# t: 15000
# ('45', 'v', '150')
# g:  4.5
# v: 150
# ('t15000', 'g', '45v160')
# t: 15000
# ('45', 'v', '160')
# g:  4.5
# v: 160
# ('t15000', 'g', '45v170')
# t: 15000
# ('45', 'v', '170')
# g:  4.5
# v: 170
# ('t15000', 'g', '45v180')
# t: 15000
# ('45', 'v', '180')
# g:  4.5
# v: 180
# ('t15000', 'g', '45v190')
# t: 15000
# ('45', 'v', '190')
# g:  4.5
# v: 190
# ('t15000', 'g', '45v200')
# t: 15000
# ('45', 'v', '200')
# g:  4.5
# v: 200
# ('t15000', 'g', '45v210')
# t: 15000
# ('45', 'v', '210')
# g:  4.5
# v: 210
# ('t15000', 'g', '45v220')
# t: 15000
# ('45', 'v', '220')
# g:  4.5
# v: 220
# ('t15000', 'g', '45v230')
# t: 15000
# ('45', 'v', '230')
# g:  4.5
# v: 230
# ('t15000', 'g', '45v240')
# t: 15000
# ('45', 'v', '240')
# g:  4.5
# v: 240
# ('t15000', 'g', '45v250')
# t: 15000
# ('45', 'v', '250')
# g:  4.5
# v: 250
# ('t15000', 'g', '45v260')
# t: 15000
# ('45', 'v', '260')
# g:  4.5
# v: 260
# ('t15000', 'g', '45v270')
# t: 15000
# ('45', 'v', '270')
# g:  4.5
# v: 270
# ('t15000', 'g', '45v280')
# t: 15000
# ('45', 'v', '280')
# g:  4.5
# v: 280
# ('t15000', 'g', '45v290')
# t: 15000
# ('45', 'v', '290')
# g:  4.5
# v: 290
# ('t15000', 'g', '45v300')
# t: 15000
# ('45', 'v', '300')
# g:  4.5
# v: 300
# ('t15000', 'g', '45v310')
# t: 15000
# ('45', 'v', '310')
# g:  4.5
# v: 310
# ('t15000', 'g', '45v320')
# t: 15000
# ('45', 'v', '320')
# g:  4.5
# v: 320
# ('t15000', 'g', '45v330')
# t: 15000
# ('45', 'v', '330')
# g:  4.5
# v: 330
# ('t15000', 'g', '45v340')
# t: 15000
# ('45', 'v', '340')
# g:  4.5
# v: 340
# ('t15000', 'g', '45v350')
# t: 15000
# ('45', 'v', '350')
# g:  4.5
# v: 350
# ('t15000', 'g', '45v360')
# t: 15000
# ('45', 'v', '360')
# g:  4.5
# v: 360
# ('t15000', 'g', '45v370')
# t: 15000
# ('45', 'v', '370')
# g:  4.5
# v: 370
# ('t15000', 'g', '45v380')
# t: 15000
# ('45', 'v', '380')
# g:  4.5
# v: 380
# ('t15000', 'g', '45v390')
# t: 15000
# ('45', 'v', '390')
# g:  4.5
# v: 390
# ('t15000', 'g', '45v400')
# t: 15000
# ('45', 'v', '400')
# g:  4.5
# v: 400
# ('t15000', 'g', '50v100')
# t: 15000
# ('50', 'v', '100')
# g:  5.0
# v: 100
# ('t15000', 'g', '50v110')
# t: 15000
# ('50', 'v', '110')
# g:  5.0
# v: 110
# ('t15000', 'g', '50v120')
# t: 15000
# ('50', 'v', '120')
# g:  5.0
# v: 120
# ('t15000', 'g', '50v130')
# t: 15000
# ('50', 'v', '130')
# g:  5.0
# v: 130
# ('t15000', 'g', '50v140')
# t: 15000
# ('50', 'v', '140')
# g:  5.0
# v: 140
# ('t15000', 'g', '50v150')
# t: 15000
# ('50', 'v', '150')
# g:  5.0
# v: 150
# ('t15000', 'g', '50v160')
# t: 15000
# ('50', 'v', '160')
# g:  5.0
# v: 160
# ('t15000', 'g', '50v170')
# t: 15000
# ('50', 'v', '170')
# g:  5.0
# v: 170
# ('t15000', 'g', '50v180')
# t: 15000
# ('50', 'v', '180')
# g:  5.0
# v: 180
# ('t15000', 'g', '50v190')
# t: 15000
# ('50', 'v', '190')
# g:  5.0
# v: 190
# ('t15000', 'g', '50v200')
# t: 15000
# ('50', 'v', '200')
# g:  5.0
# v: 200
# ('t15000', 'g', '50v210')
# t: 15000
# ('50', 'v', '210')
# g:  5.0
# v: 210
# ('t15000', 'g', '50v220')
# t: 15000
# ('50', 'v', '220')
# g:  5.0
# v: 220
# ('t15000', 'g', '50v230')
# t: 15000
# ('50', 'v', '230')
# g:  5.0
# v: 230
# ('t15000', 'g', '50v240')
# t: 15000
# ('50', 'v', '240')
# g:  5.0
# v: 240
# ('t15000', 'g', '50v250')
# t: 15000
# ('50', 'v', '250')
# g:  5.0
# v: 250
# ('t15000', 'g', '50v260')
# t: 15000
# ('50', 'v', '260')
# g:  5.0
# v: 260
# ('t15000', 'g', '50v270')
# t: 15000
# ('50', 'v', '270')
# g:  5.0
# v: 270
# ('t15000', 'g', '50v280')
# t: 15000
# ('50', 'v', '280')
# g:  5.0
# v: 280
# ('t15000', 'g', '50v290')
# t: 15000
# ('50', 'v', '290')
# g:  5.0
# v: 290
# ('t15000', 'g', '50v300')
# t: 15000
# ('50', 'v', '300')
# g:  5.0
# v: 300
# ('t15000', 'g', '50v310')
# t: 15000
# ('50', 'v', '310')
# g:  5.0
# v: 310
# ('t15000', 'g', '50v320')
# t: 15000
# ('50', 'v', '320')
# g:  5.0
# v: 320
# ('t15000', 'g', '50v330')
# t: 15000
# ('50', 'v', '330')
# g:  5.0
# v: 330
# ('t15000', 'g', '50v340')
# t: 15000
# ('50', 'v', '340')
# g:  5.0
# v: 340
# ('t15000', 'g', '50v350')
# t: 15000
# ('50', 'v', '350')
# g:  5.0
# v: 350
# ('t15000', 'g', '50v360')
# t: 15000
# ('50', 'v', '360')
# g:  5.0
# v: 360
# ('t15000', 'g', '50v370')
# t: 15000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# ('t15000', 'g', '50v380')
# t: 15000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# ('t15000', 'g', '50v390')
# t: 15000
# ('50', 'v', '390')
# g:  5.0
# v: 390
# ('t15000', 'g', '50v400')
# t: 15000
# ('50', 'v', '400')
# g:  5.0
# v: 400
# ('t16000', 'g', '20v100')
# t: 16000
# ('20', 'v', '100')
# g:  2.0
# v: 100
# ('t16000', 'g', '20v110')
# t: 16000
# ('20', 'v', '110')
# g:  2.0
# v: 110
# ('t16000', 'g', '20v120')
# t: 16000
# ('20', 'v', '120')
# g:  2.0
# v: 120
# ('t16000', 'g', '20v130')
# t: 16000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# ('t16000', 'g', '20v140')
# t: 16000
# ('20', 'v', '140')
# g:  2.0
# v: 140
# ('t16000', 'g', '20v150')
# t: 16000
# ('20', 'v', '150')
# g:  2.0
# v: 150
# ('t16000', 'g', '20v160')
# t: 16000
# ('20', 'v', '160')
# g:  2.0
# v: 160
# ('t16000', 'g', '20v170')
# t: 16000
# ('20', 'v', '170')
# g:  2.0
# v: 170
# ('t16000', 'g', '20v180')
# t: 16000
# ('20', 'v', '180')
# g:  2.0
# v: 180
# ('t16000', 'g', '20v190')
# t: 16000
# ('20', 'v', '190')
# g:  2.0
# v: 190
# ('t16000', 'g', '20v200')
# t: 16000
# ('20', 'v', '200')
# g:  2.0
# v: 200
# ('t16000', 'g', '20v210')
# t: 16000
# ('20', 'v', '210')
# g:  2.0
# v: 210
# ('t16000', 'g', '20v220')
# t: 16000
# ('20', 'v', '220')
# g:  2.0
# v: 220
# ('t16000', 'g', '20v230')
# t: 16000
# ('20', 'v', '230')
# g:  2.0
# v: 230
# ('t16000', 'g', '20v240')
# t: 16000
# ('20', 'v', '240')
# g:  2.0
# v: 240
# ('t16000', 'g', '20v250')
# t: 16000
# ('20', 'v', '250')
# g:  2.0
# v: 250
# ('t16000', 'g', '20v260')
# t: 16000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# ('t16000', 'g', '20v270')
# t: 16000
# ('20', 'v', '270')
# g:  2.0
# v: 270
# ('t16000', 'g', '20v280')
# t: 16000
# ('20', 'v', '280')
# g:  2.0
# v: 280
# ('t16000', 'g', '20v290')
# t: 16000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# ('t16000', 'g', '20v300')
# t: 16000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# ('t16000', 'g', '20v310')
# t: 16000
# ('20', 'v', '310')
# g:  2.0
# v: 310
# ('t16000', 'g', '20v320')
# t: 16000
# ('20', 'v', '320')
# g:  2.0
# v: 320
# ('t16000', 'g', '20v330')
# t: 16000
# ('20', 'v', '330')
# g:  2.0
# v: 330
# ('t16000', 'g', '20v340')
# t: 16000
# ('20', 'v', '340')
# g:  2.0
# v: 340
# ('t16000', 'g', '20v350')
# t: 16000
# ('20', 'v', '350')
# g:  2.0
# v: 350
# ('t16000', 'g', '20v360')
# t: 16000
# ('20', 'v', '360')
# g:  2.0
# v: 360
# ('t16000', 'g', '20v370')
# t: 16000
# ('20', 'v', '370')
# g:  2.0
# v: 370
# ('t16000', 'g', '20v380')
# t: 16000
# ('20', 'v', '380')
# g:  2.0
# v: 380
# ('t16000', 'g', '20v390')
# t: 16000
# ('20', 'v', '390')
# g:  2.0
# v: 390
# ('t16000', 'g', '20v400')
# t: 16000
# ('20', 'v', '400')
# g:  2.0
# v: 400
# ('t16000', 'g', '25v100')
# t: 16000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# ('t16000', 'g', '25v110')
# t: 16000
# ('25', 'v', '110')
# g:  2.5
# v: 110
# ('t16000', 'g', '25v120')
# t: 16000
# ('25', 'v', '120')
# g:  2.5
# v: 120
# ('t16000', 'g', '25v130')
# t: 16000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# ('t16000', 'g', '25v140')
# t: 16000
# ('25', 'v', '140')
# g:  2.5
# v: 140
# ('t16000', 'g', '25v150')
# t: 16000
# ('25', 'v', '150')
# g:  2.5
# v: 150
# ('t16000', 'g', '25v160')
# t: 16000
# ('25', 'v', '160')
# g:  2.5
# v: 160
# ('t16000', 'g', '25v170')
# t: 16000
# ('25', 'v', '170')
# g:  2.5
# v: 170
# ('t16000', 'g', '25v180')
# t: 16000
# ('25', 'v', '180')
# g:  2.5
# v: 180
# ('t16000', 'g', '25v190')
# t: 16000
# ('25', 'v', '190')
# g:  2.5
# v: 190
# ('t16000', 'g', '25v200')
# t: 16000
# ('25', 'v', '200')
# g:  2.5
# v: 200
# ('t16000', 'g', '25v210')
# t: 16000
# ('25', 'v', '210')
# g:  2.5
# v: 210
# ('t16000', 'g', '25v220')
# t: 16000
# ('25', 'v', '220')
# g:  2.5
# v: 220
# ('t16000', 'g', '25v230')
# t: 16000
# ('25', 'v', '230')
# g:  2.5
# v: 230
# ('t16000', 'g', '25v240')
# t: 16000
# ('25', 'v', '240')
# g:  2.5
# v: 240
# ('t16000', 'g', '25v250')
# t: 16000
# ('25', 'v', '250')
# g:  2.5
# v: 250
# ('t16000', 'g', '25v260')
# t: 16000
# ('25', 'v', '260')
# g:  2.5
# v: 260
# ('t16000', 'g', '25v270')
# t: 16000
# ('25', 'v', '270')
# g:  2.5
# v: 270
# ('t16000', 'g', '25v280')
# t: 16000
# ('25', 'v', '280')
# g:  2.5
# v: 280
# ('t16000', 'g', '25v290')
# t: 16000
# ('25', 'v', '290')
# g:  2.5
# v: 290
# ('t16000', 'g', '25v300')
# t: 16000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# ('t16000', 'g', '25v310')
# t: 16000
# ('25', 'v', '310')
# g:  2.5
# v: 310
# ('t16000', 'g', '25v320')
# t: 16000
# ('25', 'v', '320')
# g:  2.5
# v: 320
# ('t16000', 'g', '25v330')
# t: 16000
# ('25', 'v', '330')
# g:  2.5
# v: 330
# ('t16000', 'g', '25v340')
# t: 16000
# ('25', 'v', '340')
# g:  2.5
# v: 340
# ('t16000', 'g', '25v350')
# t: 16000
# ('25', 'v', '350')
# g:  2.5
# v: 350
# ('t16000', 'g', '25v360')
# t: 16000
# ('25', 'v', '360')
# g:  2.5
# v: 360
# ('t16000', 'g', '25v370')
# t: 16000
# ('25', 'v', '370')
# g:  2.5
# v: 370
# ('t16000', 'g', '25v380')
# t: 16000
# ('25', 'v', '380')
# g:  2.5
# v: 380
# ('t16000', 'g', '25v390')
# t: 16000
# ('25', 'v', '390')
# g:  2.5
# v: 390
# ('t16000', 'g', '25v400')
# t: 16000
# ('25', 'v', '400')
# g:  2.5
# v: 400
# ('t16000', 'g', '30v100')
# t: 16000
# ('30', 'v', '100')
# g:  3.0
# v: 100
# ('t16000', 'g', '30v110')
# t: 16000
# ('30', 'v', '110')
# g:  3.0
# v: 110
# ('t16000', 'g', '30v120')
# t: 16000
# ('30', 'v', '120')
# g:  3.0
# v: 120
# ('t16000', 'g', '30v130')
# t: 16000
# ('30', 'v', '130')
# g:  3.0
# v: 130
# ('t16000', 'g', '30v140')
# t: 16000
# ('30', 'v', '140')
# g:  3.0
# v: 140
# ('t16000', 'g', '30v150')
# t: 16000
# ('30', 'v', '150')
# g:  3.0
# v: 150
# ('t16000', 'g', '30v160')
# t: 16000
# ('30', 'v', '160')
# g:  3.0
# v: 160
# ('t16000', 'g', '30v170')
# t: 16000
# ('30', 'v', '170')
# g:  3.0
# v: 170
# ('t16000', 'g', '30v180')
# t: 16000
# ('30', 'v', '180')
# g:  3.0
# v: 180
# ('t16000', 'g', '30v190')
# t: 16000
# ('30', 'v', '190')
# g:  3.0
# v: 190
# ('t16000', 'g', '30v200')
# t: 16000
# ('30', 'v', '200')
# g:  3.0
# v: 200
# ('t16000', 'g', '30v210')
# t: 16000
# ('30', 'v', '210')
# g:  3.0
# v: 210
# ('t16000', 'g', '30v220')
# t: 16000
# ('30', 'v', '220')
# g:  3.0
# v: 220
# ('t16000', 'g', '30v230')
# t: 16000
# ('30', 'v', '230')
# g:  3.0
# v: 230
# ('t16000', 'g', '30v240')
# t: 16000
# ('30', 'v', '240')
# g:  3.0
# v: 240
# ('t16000', 'g', '30v250')
# t: 16000
# ('30', 'v', '250')
# g:  3.0
# v: 250
# ('t16000', 'g', '30v260')
# t: 16000
# ('30', 'v', '260')
# g:  3.0
# v: 260
# ('t16000', 'g', '30v270')
# t: 16000
# ('30', 'v', '270')
# g:  3.0
# v: 270
# ('t16000', 'g', '30v280')
# t: 16000
# ('30', 'v', '280')
# g:  3.0
# v: 280
# ('t16000', 'g', '30v290')
# t: 16000
# ('30', 'v', '290')
# g:  3.0
# v: 290
# ('t16000', 'g', '30v300')
# t: 16000
# ('30', 'v', '300')
# g:  3.0
# v: 300
# ('t16000', 'g', '30v310')
# t: 16000
# ('30', 'v', '310')
# g:  3.0
# v: 310
# ('t16000', 'g', '30v320')
# t: 16000
# ('30', 'v', '320')
# g:  3.0
# v: 320
# ('t16000', 'g', '30v330')
# t: 16000
# ('30', 'v', '330')
# g:  3.0
# v: 330
# ('t16000', 'g', '30v340')
# t: 16000
# ('30', 'v', '340')
# g:  3.0
# v: 340
# ('t16000', 'g', '30v350')
# t: 16000
# ('30', 'v', '350')
# g:  3.0
# v: 350
# ('t16000', 'g', '30v360')
# t: 16000
# ('30', 'v', '360')
# g:  3.0
# v: 360
# ('t16000', 'g', '30v370')
# t: 16000
# ('30', 'v', '370')
# g:  3.0
# v: 370
# ('t16000', 'g', '30v380')
# t: 16000
# ('30', 'v', '380')
# g:  3.0
# v: 380
# ('t16000', 'g', '30v390')
# t: 16000
# ('30', 'v', '390')
# g:  3.0
# v: 390
# ('t16000', 'g', '30v400')
# t: 16000
# ('30', 'v', '400')
# g:  3.0
# v: 400
# ('t16000', 'g', '35v100')
# t: 16000
# ('35', 'v', '100')
# g:  3.5
# v: 100
# ('t16000', 'g', '35v110')
# t: 16000
# ('35', 'v', '110')
# g:  3.5
# v: 110
# ('t16000', 'g', '35v120')
# t: 16000
# ('35', 'v', '120')
# g:  3.5
# v: 120
# ('t16000', 'g', '35v130')
# t: 16000
# ('35', 'v', '130')
# g:  3.5
# v: 130
# ('t16000', 'g', '35v140')
# t: 16000
# ('35', 'v', '140')
# g:  3.5
# v: 140
# ('t16000', 'g', '35v150')
# t: 16000
# ('35', 'v', '150')
# g:  3.5
# v: 150
# ('t16000', 'g', '35v160')
# t: 16000
# ('35', 'v', '160')
# g:  3.5
# v: 160
# ('t16000', 'g', '35v170')
# t: 16000
# ('35', 'v', '170')
# g:  3.5
# v: 170
# ('t16000', 'g', '35v180')
# t: 16000
# ('35', 'v', '180')
# g:  3.5
# v: 180
# ('t16000', 'g', '35v190')
# t: 16000
# ('35', 'v', '190')
# g:  3.5
# v: 190
# ('t16000', 'g', '35v200')
# t: 16000
# ('35', 'v', '200')
# g:  3.5
# v: 200
# ('t16000', 'g', '35v210')
# t: 16000
# ('35', 'v', '210')
# g:  3.5
# v: 210
# ('t16000', 'g', '35v220')
# t: 16000
# ('35', 'v', '220')
# g:  3.5
# v: 220
# ('t16000', 'g', '35v230')
# t: 16000
# ('35', 'v', '230')
# g:  3.5
# v: 230
# ('t16000', 'g', '35v240')
# t: 16000
# ('35', 'v', '240')
# g:  3.5
# v: 240
# ('t16000', 'g', '35v250')
# t: 16000
# ('35', 'v', '250')
# g:  3.5
# v: 250
# ('t16000', 'g', '35v260')
# t: 16000
# ('35', 'v', '260')
# g:  3.5
# v: 260
# ('t16000', 'g', '35v270')
# t: 16000
# ('35', 'v', '270')
# g:  3.5
# v: 270
# ('t16000', 'g', '35v280')
# t: 16000
# ('35', 'v', '280')
# g:  3.5
# v: 280
# ('t16000', 'g', '35v290')
# t: 16000
# ('35', 'v', '290')
# g:  3.5
# v: 290
# ('t16000', 'g', '35v300')
# t: 16000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# ('t16000', 'g', '35v310')
# t: 16000
# ('35', 'v', '310')
# g:  3.5
# v: 310
# ('t16000', 'g', '35v320')
# t: 16000
# ('35', 'v', '320')
# g:  3.5
# v: 320
# ('t16000', 'g', '35v330')
# t: 16000
# ('35', 'v', '330')
# g:  3.5
# v: 330
# ('t16000', 'g', '35v340')
# t: 16000
# ('35', 'v', '340')
# g:  3.5
# v: 340
# ('t16000', 'g', '35v350')
# t: 16000
# ('35', 'v', '350')
# g:  3.5
# v: 350
# ('t16000', 'g', '35v360')
# t: 16000
# ('35', 'v', '360')
# g:  3.5
# v: 360
# ('t16000', 'g', '35v370')
# t: 16000
# ('35', 'v', '370')
# g:  3.5
# v: 370
# ('t16000', 'g', '35v380')
# t: 16000
# ('35', 'v', '380')
# g:  3.5
# v: 380
# ('t16000', 'g', '35v390')
# t: 16000
# ('35', 'v', '390')
# g:  3.5
# v: 390
# ('t16000', 'g', '35v400')
# t: 16000
# ('35', 'v', '400')
# g:  3.5
# v: 400
# ('t16000', 'g', '40v100')
# t: 16000
# ('40', 'v', '100')
# g:  4.0
# v: 100
# ('t16000', 'g', '40v110')
# t: 16000
# ('40', 'v', '110')
# g:  4.0
# v: 110
# ('t16000', 'g', '40v120')
# t: 16000
# ('40', 'v', '120')
# g:  4.0
# v: 120
# ('t16000', 'g', '40v130')
# t: 16000
# ('40', 'v', '130')
# g:  4.0
# v: 130
# ('t16000', 'g', '40v140')
# t: 16000
# ('40', 'v', '140')
# g:  4.0
# v: 140
# ('t16000', 'g', '40v150')
# t: 16000
# ('40', 'v', '150')
# g:  4.0
# v: 150
# ('t16000', 'g', '40v160')
# t: 16000
# ('40', 'v', '160')
# g:  4.0
# v: 160
# ('t16000', 'g', '40v170')
# t: 16000
# ('40', 'v', '170')
# g:  4.0
# v: 170
# ('t16000', 'g', '40v180')
# t: 16000
# ('40', 'v', '180')
# g:  4.0
# v: 180
# ('t16000', 'g', '40v190')
# t: 16000
# ('40', 'v', '190')
# g:  4.0
# v: 190
# ('t16000', 'g', '40v200')
# t: 16000
# ('40', 'v', '200')
# g:  4.0
# v: 200
# ('t16000', 'g', '40v210')
# t: 16000
# ('40', 'v', '210')
# g:  4.0
# v: 210
# ('t16000', 'g', '40v220')
# t: 16000
# ('40', 'v', '220')
# g:  4.0
# v: 220
# ('t16000', 'g', '40v230')
# t: 16000
# ('40', 'v', '230')
# g:  4.0
# v: 230
# ('t16000', 'g', '40v240')
# t: 16000
# ('40', 'v', '240')
# g:  4.0
# v: 240
# ('t16000', 'g', '40v250')
# t: 16000
# ('40', 'v', '250')
# g:  4.0
# v: 250
# ('t16000', 'g', '40v260')
# t: 16000
# ('40', 'v', '260')
# g:  4.0
# v: 260
# ('t16000', 'g', '40v270')
# t: 16000
# ('40', 'v', '270')
# g:  4.0
# v: 270
# ('t16000', 'g', '40v280')
# t: 16000
# ('40', 'v', '280')
# g:  4.0
# v: 280
# ('t16000', 'g', '40v290')
# t: 16000
# ('40', 'v', '290')
# g:  4.0
# v: 290
# ('t16000', 'g', '40v300')
# t: 16000
# ('40', 'v', '300')
# g:  4.0
# v: 300
# ('t16000', 'g', '40v310')
# t: 16000
# ('40', 'v', '310')
# g:  4.0
# v: 310
# ('t16000', 'g', '40v320')
# t: 16000
# ('40', 'v', '320')
# g:  4.0
# v: 320
# ('t16000', 'g', '40v330')
# t: 16000
# ('40', 'v', '330')
# g:  4.0
# v: 330
# ('t16000', 'g', '40v340')
# t: 16000
# ('40', 'v', '340')
# g:  4.0
# v: 340
# ('t16000', 'g', '40v350')
# t: 16000
# ('40', 'v', '350')
# g:  4.0
# v: 350
# ('t16000', 'g', '40v360')
# t: 16000
# ('40', 'v', '360')
# g:  4.0
# v: 360
# ('t16000', 'g', '40v370')
# t: 16000
# ('40', 'v', '370')
# g:  4.0
# v: 370
# ('t16000', 'g', '40v380')
# t: 16000
# ('40', 'v', '380')
# g:  4.0
# v: 380
# ('t16000', 'g', '40v390')
# t: 16000
# ('40', 'v', '390')
# g:  4.0
# v: 390
# ('t16000', 'g', '40v400')
# t: 16000
# ('40', 'v', '400')
# g:  4.0
# v: 400
# ('t16000', 'g', '45v100')
# t: 16000
# ('45', 'v', '100')
# g:  4.5
# v: 100
# ('t16000', 'g', '45v110')
# t: 16000
# ('45', 'v', '110')
# g:  4.5
# v: 110
# ('t16000', 'g', '45v120')
# t: 16000
# ('45', 'v', '120')
# g:  4.5
# v: 120
# ('t16000', 'g', '45v130')
# t: 16000
# ('45', 'v', '130')
# g:  4.5
# v: 130
# ('t16000', 'g', '45v140')
# t: 16000
# ('45', 'v', '140')
# g:  4.5
# v: 140
# ('t16000', 'g', '45v150')
# t: 16000
# ('45', 'v', '150')
# g:  4.5
# v: 150
# ('t16000', 'g', '45v160')
# t: 16000
# ('45', 'v', '160')
# g:  4.5
# v: 160
# ('t16000', 'g', '45v170')
# t: 16000
# ('45', 'v', '170')
# g:  4.5
# v: 170
# ('t16000', 'g', '45v180')
# t: 16000
# ('45', 'v', '180')
# g:  4.5
# v: 180
# ('t16000', 'g', '45v190')
# t: 16000
# ('45', 'v', '190')
# g:  4.5
# v: 190
# ('t16000', 'g', '45v200')
# t: 16000
# ('45', 'v', '200')
# g:  4.5
# v: 200
# ('t16000', 'g', '45v210')
# t: 16000
# ('45', 'v', '210')
# g:  4.5
# v: 210
# ('t16000', 'g', '45v220')
# t: 16000
# ('45', 'v', '220')
# g:  4.5
# v: 220
# ('t16000', 'g', '45v230')
# t: 16000
# ('45', 'v', '230')
# g:  4.5
# v: 230
# ('t16000', 'g', '45v240')
# t: 16000
# ('45', 'v', '240')
# g:  4.5
# v: 240
# ('t16000', 'g', '45v250')
# t: 16000
# ('45', 'v', '250')
# g:  4.5
# v: 250
# ('t16000', 'g', '45v260')
# t: 16000
# ('45', 'v', '260')
# g:  4.5
# v: 260
# ('t16000', 'g', '45v270')
# t: 16000
# ('45', 'v', '270')
# g:  4.5
# v: 270
# ('t16000', 'g', '45v280')
# t: 16000
# ('45', 'v', '280')
# g:  4.5
# v: 280
# ('t16000', 'g', '45v290')
# t: 16000
# ('45', 'v', '290')
# g:  4.5
# v: 290
# ('t16000', 'g', '45v300')
# t: 16000
# ('45', 'v', '300')
# g:  4.5
# v: 300
# ('t16000', 'g', '45v310')
# t: 16000
# ('45', 'v', '310')
# g:  4.5
# v: 310
# ('t16000', 'g', '45v320')
# t: 16000
# ('45', 'v', '320')
# g:  4.5
# v: 320
# ('t16000', 'g', '45v330')
# t: 16000
# ('45', 'v', '330')
# g:  4.5
# v: 330
# ('t16000', 'g', '45v340')
# t: 16000
# ('45', 'v', '340')
# g:  4.5
# v: 340
# ('t16000', 'g', '45v350')
# t: 16000
# ('45', 'v', '350')
# g:  4.5
# v: 350
# ('t16000', 'g', '45v360')
# t: 16000
# ('45', 'v', '360')
# g:  4.5
# v: 360
# ('t16000', 'g', '45v370')
# t: 16000
# ('45', 'v', '370')
# g:  4.5
# v: 370
# ('t16000', 'g', '45v380')
# t: 16000
# ('45', 'v', '380')
# g:  4.5
# v: 380
# ('t16000', 'g', '45v390')
# t: 16000
# ('45', 'v', '390')
# g:  4.5
# v: 390
# ('t16000', 'g', '45v400')
# t: 16000
# ('45', 'v', '400')
# g:  4.5
# v: 400
# ('t16000', 'g', '50v100')
# t: 16000
# ('50', 'v', '100')
# g:  5.0
# v: 100
# ('t16000', 'g', '50v110')
# t: 16000
# ('50', 'v', '110')
# g:  5.0
# v: 110
# ('t16000', 'g', '50v120')
# t: 16000
# ('50', 'v', '120')
# g:  5.0
# v: 120
# ('t16000', 'g', '50v130')
# t: 16000
# ('50', 'v', '130')
# g:  5.0
# v: 130
# ('t16000', 'g', '50v140')
# t: 16000
# ('50', 'v', '140')
# g:  5.0
# v: 140
# ('t16000', 'g', '50v150')
# t: 16000
# ('50', 'v', '150')
# g:  5.0
# v: 150
# ('t16000', 'g', '50v160')
# t: 16000
# ('50', 'v', '160')
# g:  5.0
# v: 160
# ('t16000', 'g', '50v170')
# t: 16000
# ('50', 'v', '170')
# g:  5.0
# v: 170
# ('t16000', 'g', '50v180')
# t: 16000
# ('50', 'v', '180')
# g:  5.0
# v: 180
# ('t16000', 'g', '50v190')
# t: 16000
# ('50', 'v', '190')
# g:  5.0
# v: 190
# ('t16000', 'g', '50v200')
# t: 16000
# ('50', 'v', '200')
# g:  5.0
# v: 200
# ('t16000', 'g', '50v210')
# t: 16000
# ('50', 'v', '210')
# g:  5.0
# v: 210
# ('t16000', 'g', '50v220')
# t: 16000
# ('50', 'v', '220')
# g:  5.0
# v: 220
# ('t16000', 'g', '50v230')
# t: 16000
# ('50', 'v', '230')
# g:  5.0
# v: 230
# ('t16000', 'g', '50v240')
# t: 16000
# ('50', 'v', '240')
# g:  5.0
# v: 240
# ('t16000', 'g', '50v250')
# t: 16000
# ('50', 'v', '250')
# g:  5.0
# v: 250
# ('t16000', 'g', '50v260')
# t: 16000
# ('50', 'v', '260')
# g:  5.0
# v: 260
# ('t16000', 'g', '50v270')
# t: 16000
# ('50', 'v', '270')
# g:  5.0
# v: 270
# ('t16000', 'g', '50v280')
# t: 16000
# ('50', 'v', '280')
# g:  5.0
# v: 280
# ('t16000', 'g', '50v290')
# t: 16000
# ('50', 'v', '290')
# g:  5.0
# v: 290
# ('t16000', 'g', '50v300')
# t: 16000
# ('50', 'v', '300')
# g:  5.0
# v: 300
# ('t16000', 'g', '50v310')
# t: 16000
# ('50', 'v', '310')
# g:  5.0
# v: 310
# ('t16000', 'g', '50v320')
# t: 16000
# ('50', 'v', '320')
# g:  5.0
# v: 320
# ('t16000', 'g', '50v330')
# t: 16000
# ('50', 'v', '330')
# g:  5.0
# v: 330
# ('t16000', 'g', '50v340')
# t: 16000
# ('50', 'v', '340')
# g:  5.0
# v: 340
# ('t16000', 'g', '50v350')
# t: 16000
# ('50', 'v', '350')
# g:  5.0
# v: 350
# ('t16000', 'g', '50v360')
# t: 16000
# ('50', 'v', '360')
# g:  5.0
# v: 360
# ('t16000', 'g', '50v370')
# t: 16000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# ('t16000', 'g', '50v380')
# t: 16000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# ('t16000', 'g', '50v390')
# t: 16000
# ('50', 'v', '390')
# g:  5.0
# v: 390
# ('t16000', 'g', '50v400')
# t: 16000
# ('50', 'v', '400')
# g:  5.0
# v: 400
# ('t17000', 'g', '20v100')
# t: 17000
# ('20', 'v', '100')
# g:  2.0
# v: 100
# ('t17000', 'g', '20v110')
# t: 17000
# ('20', 'v', '110')
# g:  2.0
# v: 110
# ('t17000', 'g', '20v120')
# t: 17000
# ('20', 'v', '120')
# g:  2.0
# v: 120
# ('t17000', 'g', '20v130')
# t: 17000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# ('t17000', 'g', '20v140')
# t: 17000
# ('20', 'v', '140')
# g:  2.0
# v: 140
# ('t17000', 'g', '20v150')
# t: 17000
# ('20', 'v', '150')
# g:  2.0
# v: 150
# ('t17000', 'g', '20v160')
# t: 17000
# ('20', 'v', '160')
# g:  2.0
# v: 160
# ('t17000', 'g', '20v170')
# t: 17000
# ('20', 'v', '170')
# g:  2.0
# v: 170
# ('t17000', 'g', '20v180')
# t: 17000
# ('20', 'v', '180')
# g:  2.0
# v: 180
# ('t17000', 'g', '20v190')
# t: 17000
# ('20', 'v', '190')
# g:  2.0
# v: 190
# ('t17000', 'g', '20v200')
# t: 17000
# ('20', 'v', '200')
# g:  2.0
# v: 200
# ('t17000', 'g', '20v210')
# t: 17000
# ('20', 'v', '210')
# g:  2.0
# v: 210
# ('t17000', 'g', '20v220')
# t: 17000
# ('20', 'v', '220')
# g:  2.0
# v: 220
# ('t17000', 'g', '20v230')
# t: 17000
# ('20', 'v', '230')
# g:  2.0
# v: 230
# ('t17000', 'g', '20v240')
# t: 17000
# ('20', 'v', '240')
# g:  2.0
# v: 240
# ('t17000', 'g', '20v250')
# t: 17000
# ('20', 'v', '250')
# g:  2.0
# v: 250
# ('t17000', 'g', '20v260')
# t: 17000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# ('t17000', 'g', '20v270')
# t: 17000
# ('20', 'v', '270')
# g:  2.0
# v: 270
# ('t17000', 'g', '20v280')
# t: 17000
# ('20', 'v', '280')
# g:  2.0
# v: 280
# ('t17000', 'g', '20v290')
# t: 17000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# ('t17000', 'g', '20v300')
# t: 17000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# ('t17000', 'g', '20v310')
# t: 17000
# ('20', 'v', '310')
# g:  2.0
# v: 310
# ('t17000', 'g', '20v320')
# t: 17000
# ('20', 'v', '320')
# g:  2.0
# v: 320
# ('t17000', 'g', '20v330')
# t: 17000
# ('20', 'v', '330')
# g:  2.0
# v: 330
# ('t17000', 'g', '20v340')
# t: 17000
# ('20', 'v', '340')
# g:  2.0
# v: 340
# ('t17000', 'g', '20v350')
# t: 17000
# ('20', 'v', '350')
# g:  2.0
# v: 350
# ('t17000', 'g', '20v360')
# t: 17000
# ('20', 'v', '360')
# g:  2.0
# v: 360
# ('t17000', 'g', '20v370')
# t: 17000
# ('20', 'v', '370')
# g:  2.0
# v: 370
# ('t17000', 'g', '20v380')
# t: 17000
# ('20', 'v', '380')
# g:  2.0
# v: 380
# ('t17000', 'g', '20v390')
# t: 17000
# ('20', 'v', '390')
# g:  2.0
# v: 390
# ('t17000', 'g', '20v400')
# t: 17000
# ('20', 'v', '400')
# g:  2.0
# v: 400
# ('t17000', 'g', '25v100')
# t: 17000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# ('t17000', 'g', '25v110')
# t: 17000
# ('25', 'v', '110')
# g:  2.5
# v: 110
# ('t17000', 'g', '25v120')
# t: 17000
# ('25', 'v', '120')
# g:  2.5
# v: 120
# ('t17000', 'g', '25v130')
# t: 17000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# ('t17000', 'g', '25v140')
# t: 17000
# ('25', 'v', '140')
# g:  2.5
# v: 140
# ('t17000', 'g', '25v150')
# t: 17000
# ('25', 'v', '150')
# g:  2.5
# v: 150
# ('t17000', 'g', '25v160')
# t: 17000
# ('25', 'v', '160')
# g:  2.5
# v: 160
# ('t17000', 'g', '25v170')
# t: 17000
# ('25', 'v', '170')
# g:  2.5
# v: 170
# ('t17000', 'g', '25v180')
# t: 17000
# ('25', 'v', '180')
# g:  2.5
# v: 180
# ('t17000', 'g', '25v190')
# t: 17000
# ('25', 'v', '190')
# g:  2.5
# v: 190
# ('t17000', 'g', '25v200')
# t: 17000
# ('25', 'v', '200')
# g:  2.5
# v: 200
# ('t17000', 'g', '25v210')
# t: 17000
# ('25', 'v', '210')
# g:  2.5
# v: 210
# ('t17000', 'g', '25v220')
# t: 17000
# ('25', 'v', '220')
# g:  2.5
# v: 220
# ('t17000', 'g', '25v230')
# t: 17000
# ('25', 'v', '230')
# g:  2.5
# v: 230
# ('t17000', 'g', '25v240')
# t: 17000
# ('25', 'v', '240')
# g:  2.5
# v: 240
# ('t17000', 'g', '25v250')
# t: 17000
# ('25', 'v', '250')
# g:  2.5
# v: 250
# ('t17000', 'g', '25v260')
# t: 17000
# ('25', 'v', '260')
# g:  2.5
# v: 260
# ('t17000', 'g', '25v270')
# t: 17000
# ('25', 'v', '270')
# g:  2.5
# v: 270
# ('t17000', 'g', '25v280')
# t: 17000
# ('25', 'v', '280')
# g:  2.5
# v: 280
# ('t17000', 'g', '25v290')
# t: 17000
# ('25', 'v', '290')
# g:  2.5
# v: 290
# ('t17000', 'g', '25v300')
# t: 17000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# ('t17000', 'g', '25v310')
# t: 17000
# ('25', 'v', '310')
# g:  2.5
# v: 310
# ('t17000', 'g', '25v320')
# t: 17000
# ('25', 'v', '320')
# g:  2.5
# v: 320
# ('t17000', 'g', '25v330')
# t: 17000
# ('25', 'v', '330')
# g:  2.5
# v: 330
# ('t17000', 'g', '25v340')
# t: 17000
# ('25', 'v', '340')
# g:  2.5
# v: 340
# ('t17000', 'g', '25v350')
# t: 17000
# ('25', 'v', '350')
# g:  2.5
# v: 350
# ('t17000', 'g', '25v360')
# t: 17000
# ('25', 'v', '360')
# g:  2.5
# v: 360
# ('t17000', 'g', '25v370')
# t: 17000
# ('25', 'v', '370')
# g:  2.5
# v: 370
# ('t17000', 'g', '25v380')
# t: 17000
# ('25', 'v', '380')
# g:  2.5
# v: 380
# ('t17000', 'g', '25v390')
# t: 17000
# ('25', 'v', '390')
# g:  2.5
# v: 390
# ('t17000', 'g', '25v400')
# t: 17000
# ('25', 'v', '400')
# g:  2.5
# v: 400
# ('t17000', 'g', '30v100')
# t: 17000
# ('30', 'v', '100')
# g:  3.0
# v: 100
# ('t17000', 'g', '30v110')
# t: 17000
# ('30', 'v', '110')
# g:  3.0
# v: 110
# ('t17000', 'g', '30v120')
# t: 17000
# ('30', 'v', '120')
# g:  3.0
# v: 120
# ('t17000', 'g', '30v130')
# t: 17000
# ('30', 'v', '130')
# g:  3.0
# v: 130
# ('t17000', 'g', '30v140')
# t: 17000
# ('30', 'v', '140')
# g:  3.0
# v: 140
# ('t17000', 'g', '30v150')
# t: 17000
# ('30', 'v', '150')
# g:  3.0
# v: 150
# ('t17000', 'g', '30v160')
# t: 17000
# ('30', 'v', '160')
# g:  3.0
# v: 160
# ('t17000', 'g', '30v170')
# t: 17000
# ('30', 'v', '170')
# g:  3.0
# v: 170
# ('t17000', 'g', '30v180')
# t: 17000
# ('30', 'v', '180')
# g:  3.0
# v: 180
# ('t17000', 'g', '30v190')
# t: 17000
# ('30', 'v', '190')
# g:  3.0
# v: 190
# ('t17000', 'g', '30v200')
# t: 17000
# ('30', 'v', '200')
# g:  3.0
# v: 200
# ('t17000', 'g', '30v210')
# t: 17000
# ('30', 'v', '210')
# g:  3.0
# v: 210
# ('t17000', 'g', '30v220')
# t: 17000
# ('30', 'v', '220')
# g:  3.0
# v: 220
# ('t17000', 'g', '30v230')
# t: 17000
# ('30', 'v', '230')
# g:  3.0
# v: 230
# ('t17000', 'g', '30v240')
# t: 17000
# ('30', 'v', '240')
# g:  3.0
# v: 240
# ('t17000', 'g', '30v250')
# t: 17000
# ('30', 'v', '250')
# g:  3.0
# v: 250
# ('t17000', 'g', '30v260')
# t: 17000
# ('30', 'v', '260')
# g:  3.0
# v: 260
# ('t17000', 'g', '30v270')
# t: 17000
# ('30', 'v', '270')
# g:  3.0
# v: 270
# ('t17000', 'g', '30v280')
# t: 17000
# ('30', 'v', '280')
# g:  3.0
# v: 280
# ('t17000', 'g', '30v290')
# t: 17000
# ('30', 'v', '290')
# g:  3.0
# v: 290
# ('t17000', 'g', '30v300')
# t: 17000
# ('30', 'v', '300')
# g:  3.0
# v: 300
# ('t17000', 'g', '30v310')
# t: 17000
# ('30', 'v', '310')
# g:  3.0
# v: 310
# ('t17000', 'g', '30v320')
# t: 17000
# ('30', 'v', '320')
# g:  3.0
# v: 320
# ('t17000', 'g', '30v330')
# t: 17000
# ('30', 'v', '330')
# g:  3.0
# v: 330
# ('t17000', 'g', '30v340')
# t: 17000
# ('30', 'v', '340')
# g:  3.0
# v: 340
# ('t17000', 'g', '30v350')
# t: 17000
# ('30', 'v', '350')
# g:  3.0
# v: 350
# ('t17000', 'g', '30v360')
# t: 17000
# ('30', 'v', '360')
# g:  3.0
# v: 360
# ('t17000', 'g', '30v370')
# t: 17000
# ('30', 'v', '370')
# g:  3.0
# v: 370
# ('t17000', 'g', '30v380')
# t: 17000
# ('30', 'v', '380')
# g:  3.0
# v: 380
# ('t17000', 'g', '30v390')
# t: 17000
# ('30', 'v', '390')
# g:  3.0
# v: 390
# ('t17000', 'g', '30v400')
# t: 17000
# ('30', 'v', '400')
# g:  3.0
# v: 400
# ('t17000', 'g', '35v100')
# t: 17000
# ('35', 'v', '100')
# g:  3.5
# v: 100
# ('t17000', 'g', '35v110')
# t: 17000
# ('35', 'v', '110')
# g:  3.5
# v: 110
# ('t17000', 'g', '35v120')
# t: 17000
# ('35', 'v', '120')
# g:  3.5
# v: 120
# ('t17000', 'g', '35v130')
# t: 17000
# ('35', 'v', '130')
# g:  3.5
# v: 130
# ('t17000', 'g', '35v140')
# t: 17000
# ('35', 'v', '140')
# g:  3.5
# v: 140
# ('t17000', 'g', '35v150')
# t: 17000
# ('35', 'v', '150')
# g:  3.5
# v: 150
# ('t17000', 'g', '35v160')
# t: 17000
# ('35', 'v', '160')
# g:  3.5
# v: 160
# ('t17000', 'g', '35v170')
# t: 17000
# ('35', 'v', '170')
# g:  3.5
# v: 170
# ('t17000', 'g', '35v180')
# t: 17000
# ('35', 'v', '180')
# g:  3.5
# v: 180
# ('t17000', 'g', '35v190')
# t: 17000
# ('35', 'v', '190')
# g:  3.5
# v: 190
# ('t17000', 'g', '35v200')
# t: 17000
# ('35', 'v', '200')
# g:  3.5
# v: 200
# ('t17000', 'g', '35v210')
# t: 17000
# ('35', 'v', '210')
# g:  3.5
# v: 210
# ('t17000', 'g', '35v220')
# t: 17000
# ('35', 'v', '220')
# g:  3.5
# v: 220
# ('t17000', 'g', '35v230')
# t: 17000
# ('35', 'v', '230')
# g:  3.5
# v: 230
# ('t17000', 'g', '35v240')
# t: 17000
# ('35', 'v', '240')
# g:  3.5
# v: 240
# ('t17000', 'g', '35v250')
# t: 17000
# ('35', 'v', '250')
# g:  3.5
# v: 250
# ('t17000', 'g', '35v260')
# t: 17000
# ('35', 'v', '260')
# g:  3.5
# v: 260
# ('t17000', 'g', '35v270')
# t: 17000
# ('35', 'v', '270')
# g:  3.5
# v: 270
# ('t17000', 'g', '35v280')
# t: 17000
# ('35', 'v', '280')
# g:  3.5
# v: 280
# ('t17000', 'g', '35v290')
# t: 17000
# ('35', 'v', '290')
# g:  3.5
# v: 290
# ('t17000', 'g', '35v300')
# t: 17000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# ('t17000', 'g', '35v310')
# t: 17000
# ('35', 'v', '310')
# g:  3.5
# v: 310
# ('t17000', 'g', '35v320')
# t: 17000
# ('35', 'v', '320')
# g:  3.5
# v: 320
# ('t17000', 'g', '35v330')
# t: 17000
# ('35', 'v', '330')
# g:  3.5
# v: 330
# ('t17000', 'g', '35v340')
# t: 17000
# ('35', 'v', '340')
# g:  3.5
# v: 340
# ('t17000', 'g', '35v350')
# t: 17000
# ('35', 'v', '350')
# g:  3.5
# v: 350
# ('t17000', 'g', '35v360')
# t: 17000
# ('35', 'v', '360')
# g:  3.5
# v: 360
# ('t17000', 'g', '35v370')
# t: 17000
# ('35', 'v', '370')
# g:  3.5
# v: 370
# ('t17000', 'g', '35v380')
# t: 17000
# ('35', 'v', '380')
# g:  3.5
# v: 380
# ('t17000', 'g', '35v390')
# t: 17000
# ('35', 'v', '390')
# g:  3.5
# v: 390
# ('t17000', 'g', '35v400')
# t: 17000
# ('35', 'v', '400')
# g:  3.5
# v: 400
# ('t17000', 'g', '40v100')
# t: 17000
# ('40', 'v', '100')
# g:  4.0
# v: 100
# ('t17000', 'g', '40v110')
# t: 17000
# ('40', 'v', '110')
# g:  4.0
# v: 110
# ('t17000', 'g', '40v120')
# t: 17000
# ('40', 'v', '120')
# g:  4.0
# v: 120
# ('t17000', 'g', '40v130')
# t: 17000
# ('40', 'v', '130')
# g:  4.0
# v: 130
# ('t17000', 'g', '40v140')
# t: 17000
# ('40', 'v', '140')
# g:  4.0
# v: 140
# ('t17000', 'g', '40v150')
# t: 17000
# ('40', 'v', '150')
# g:  4.0
# v: 150
# ('t17000', 'g', '40v160')
# t: 17000
# ('40', 'v', '160')
# g:  4.0
# v: 160
# ('t17000', 'g', '40v170')
# t: 17000
# ('40', 'v', '170')
# g:  4.0
# v: 170
# ('t17000', 'g', '40v180')
# t: 17000
# ('40', 'v', '180')
# g:  4.0
# v: 180
# ('t17000', 'g', '40v190')
# t: 17000
# ('40', 'v', '190')
# g:  4.0
# v: 190
# ('t17000', 'g', '40v200')
# t: 17000
# ('40', 'v', '200')
# g:  4.0
# v: 200
# ('t17000', 'g', '40v210')
# t: 17000
# ('40', 'v', '210')
# g:  4.0
# v: 210
# ('t17000', 'g', '40v220')
# t: 17000
# ('40', 'v', '220')
# g:  4.0
# v: 220
# ('t17000', 'g', '40v230')
# t: 17000
# ('40', 'v', '230')
# g:  4.0
# v: 230
# ('t17000', 'g', '40v240')
# t: 17000
# ('40', 'v', '240')
# g:  4.0
# v: 240
# ('t17000', 'g', '40v250')
# t: 17000
# ('40', 'v', '250')
# g:  4.0
# v: 250
# ('t17000', 'g', '40v260')
# t: 17000
# ('40', 'v', '260')
# g:  4.0
# v: 260
# ('t17000', 'g', '40v270')
# t: 17000
# ('40', 'v', '270')
# g:  4.0
# v: 270
# ('t17000', 'g', '40v280')
# t: 17000
# ('40', 'v', '280')
# g:  4.0
# v: 280
# ('t17000', 'g', '40v290')
# t: 17000
# ('40', 'v', '290')
# g:  4.0
# v: 290
# ('t17000', 'g', '40v300')
# t: 17000
# ('40', 'v', '300')
# g:  4.0
# v: 300
# ('t17000', 'g', '40v310')
# t: 17000
# ('40', 'v', '310')
# g:  4.0
# v: 310
# ('t17000', 'g', '40v320')
# t: 17000
# ('40', 'v', '320')
# g:  4.0
# v: 320
# ('t17000', 'g', '40v330')
# t: 17000
# ('40', 'v', '330')
# g:  4.0
# v: 330
# ('t17000', 'g', '40v340')
# t: 17000
# ('40', 'v', '340')
# g:  4.0
# v: 340
# ('t17000', 'g', '40v350')
# t: 17000
# ('40', 'v', '350')
# g:  4.0
# v: 350
# ('t17000', 'g', '40v360')
# t: 17000
# ('40', 'v', '360')
# g:  4.0
# v: 360
# ('t17000', 'g', '40v370')
# t: 17000
# ('40', 'v', '370')
# g:  4.0
# v: 370
# ('t17000', 'g', '40v380')
# t: 17000
# ('40', 'v', '380')
# g:  4.0
# v: 380
# ('t17000', 'g', '40v390')
# t: 17000
# ('40', 'v', '390')
# g:  4.0
# v: 390
# ('t17000', 'g', '40v400')
# t: 17000
# ('40', 'v', '400')
# g:  4.0
# v: 400
# ('t17000', 'g', '45v100')
# t: 17000
# ('45', 'v', '100')
# g:  4.5
# v: 100
# ('t17000', 'g', '45v110')
# t: 17000
# ('45', 'v', '110')
# g:  4.5
# v: 110
# ('t17000', 'g', '45v120')
# t: 17000
# ('45', 'v', '120')
# g:  4.5
# v: 120
# ('t17000', 'g', '45v130')
# t: 17000
# ('45', 'v', '130')
# g:  4.5
# v: 130
# ('t17000', 'g', '45v140')
# t: 17000
# ('45', 'v', '140')
# g:  4.5
# v: 140
# ('t17000', 'g', '45v150')
# t: 17000
# ('45', 'v', '150')
# g:  4.5
# v: 150
# ('t17000', 'g', '45v160')
# t: 17000
# ('45', 'v', '160')
# g:  4.5
# v: 160
# ('t17000', 'g', '45v170')
# t: 17000
# ('45', 'v', '170')
# g:  4.5
# v: 170
# ('t17000', 'g', '45v180')
# t: 17000
# ('45', 'v', '180')
# g:  4.5
# v: 180
# ('t17000', 'g', '45v190')
# t: 17000
# ('45', 'v', '190')
# g:  4.5
# v: 190
# ('t17000', 'g', '45v200')
# t: 17000
# ('45', 'v', '200')
# g:  4.5
# v: 200
# ('t17000', 'g', '45v210')
# t: 17000
# ('45', 'v', '210')
# g:  4.5
# v: 210
# ('t17000', 'g', '45v220')
# t: 17000
# ('45', 'v', '220')
# g:  4.5
# v: 220
# ('t17000', 'g', '45v230')
# t: 17000
# ('45', 'v', '230')
# g:  4.5
# v: 230
# ('t17000', 'g', '45v240')
# t: 17000
# ('45', 'v', '240')
# g:  4.5
# v: 240
# ('t17000', 'g', '45v250')
# t: 17000
# ('45', 'v', '250')
# g:  4.5
# v: 250
# ('t17000', 'g', '45v260')
# t: 17000
# ('45', 'v', '260')
# g:  4.5
# v: 260
# ('t17000', 'g', '45v270')
# t: 17000
# ('45', 'v', '270')
# g:  4.5
# v: 270
# ('t17000', 'g', '45v280')
# t: 17000
# ('45', 'v', '280')
# g:  4.5
# v: 280
# ('t17000', 'g', '45v290')
# t: 17000
# ('45', 'v', '290')
# g:  4.5
# v: 290
# ('t17000', 'g', '45v300')
# t: 17000
# ('45', 'v', '300')
# g:  4.5
# v: 300
# ('t17000', 'g', '45v310')
# t: 17000
# ('45', 'v', '310')
# g:  4.5
# v: 310
# ('t17000', 'g', '45v320')
# t: 17000
# ('45', 'v', '320')
# g:  4.5
# v: 320
# ('t17000', 'g', '45v330')
# t: 17000
# ('45', 'v', '330')
# g:  4.5
# v: 330
# ('t17000', 'g', '45v340')
# t: 17000
# ('45', 'v', '340')
# g:  4.5
# v: 340
# ('t17000', 'g', '45v350')
# t: 17000
# ('45', 'v', '350')
# g:  4.5
# v: 350
# ('t17000', 'g', '45v360')
# t: 17000
# ('45', 'v', '360')
# g:  4.5
# v: 360
# ('t17000', 'g', '45v370')
# t: 17000
# ('45', 'v', '370')
# g:  4.5
# v: 370
# ('t17000', 'g', '45v380')
# t: 17000
# ('45', 'v', '380')
# g:  4.5
# v: 380
# ('t17000', 'g', '45v390')
# t: 17000
# ('45', 'v', '390')
# g:  4.5
# v: 390
# ('t17000', 'g', '45v400')
# t: 17000
# ('45', 'v', '400')
# g:  4.5
# v: 400
# ('t17000', 'g', '50v100')
# t: 17000
# ('50', 'v', '100')
# g:  5.0
# v: 100
# ('t17000', 'g', '50v110')
# t: 17000
# ('50', 'v', '110')
# g:  5.0
# v: 110
# ('t17000', 'g', '50v120')
# t: 17000
# ('50', 'v', '120')
# g:  5.0
# v: 120
# ('t17000', 'g', '50v130')
# t: 17000
# ('50', 'v', '130')
# g:  5.0
# v: 130
# ('t17000', 'g', '50v140')
# t: 17000
# ('50', 'v', '140')
# g:  5.0
# v: 140
# ('t17000', 'g', '50v150')
# t: 17000
# ('50', 'v', '150')
# g:  5.0
# v: 150
# ('t17000', 'g', '50v160')
# t: 17000
# ('50', 'v', '160')
# g:  5.0
# v: 160
# ('t17000', 'g', '50v170')
# t: 17000
# ('50', 'v', '170')
# g:  5.0
# v: 170
# ('t17000', 'g', '50v180')
# t: 17000
# ('50', 'v', '180')
# g:  5.0
# v: 180
# ('t17000', 'g', '50v190')
# t: 17000
# ('50', 'v', '190')
# g:  5.0
# v: 190
# ('t17000', 'g', '50v200')
# t: 17000
# ('50', 'v', '200')
# g:  5.0
# v: 200
# ('t17000', 'g', '50v210')
# t: 17000
# ('50', 'v', '210')
# g:  5.0
# v: 210
# ('t17000', 'g', '50v220')
# t: 17000
# ('50', 'v', '220')
# g:  5.0
# v: 220
# ('t17000', 'g', '50v230')
# t: 17000
# ('50', 'v', '230')
# g:  5.0
# v: 230
# ('t17000', 'g', '50v240')
# t: 17000
# ('50', 'v', '240')
# g:  5.0
# v: 240
# ('t17000', 'g', '50v250')
# t: 17000
# ('50', 'v', '250')
# g:  5.0
# v: 250
# ('t17000', 'g', '50v260')
# t: 17000
# ('50', 'v', '260')
# g:  5.0
# v: 260
# ('t17000', 'g', '50v270')
# t: 17000
# ('50', 'v', '270')
# g:  5.0
# v: 270
# ('t17000', 'g', '50v280')
# t: 17000
# ('50', 'v', '280')
# g:  5.0
# v: 280
# ('t17000', 'g', '50v290')
# t: 17000
# ('50', 'v', '290')
# g:  5.0
# v: 290
# ('t17000', 'g', '50v300')
# t: 17000
# ('50', 'v', '300')
# g:  5.0
# v: 300
# ('t17000', 'g', '50v310')
# t: 17000
# ('50', 'v', '310')
# g:  5.0
# v: 310
# ('t17000', 'g', '50v320')
# t: 17000
# ('50', 'v', '320')
# g:  5.0
# v: 320
# ('t17000', 'g', '50v330')
# t: 17000
# ('50', 'v', '330')
# g:  5.0
# v: 330
# ('t17000', 'g', '50v340')
# t: 17000
# ('50', 'v', '340')
# g:  5.0
# v: 340
# ('t17000', 'g', '50v350')
# t: 17000
# ('50', 'v', '350')
# g:  5.0
# v: 350
# ('t17000', 'g', '50v360')
# t: 17000
# ('50', 'v', '360')
# g:  5.0
# v: 360
# ('t17000', 'g', '50v370')
# t: 17000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# ('t17000', 'g', '50v380')
# t: 17000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# ('t17000', 'g', '50v390')
# t: 17000
# ('50', 'v', '390')
# g:  5.0
# v: 390
# ('t17000', 'g', '50v400')
# t: 17000
# ('50', 'v', '400')
# g:  5.0
# v: 400
# ('t18000', 'g', '20v100')
# t: 18000
# ('20', 'v', '100')
# g:  2.0
# v: 100
# ('t18000', 'g', '20v110')
# t: 18000
# ('20', 'v', '110')
# g:  2.0
# v: 110
# ('t18000', 'g', '20v120')
# t: 18000
# ('20', 'v', '120')
# g:  2.0
# v: 120
# ('t18000', 'g', '20v130')
# t: 18000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# ('t18000', 'g', '20v140')
# t: 18000
# ('20', 'v', '140')
# g:  2.0
# v: 140
# ('t18000', 'g', '20v150')
# t: 18000
# ('20', 'v', '150')
# g:  2.0
# v: 150
# ('t18000', 'g', '20v160')
# t: 18000
# ('20', 'v', '160')
# g:  2.0
# v: 160
# ('t18000', 'g', '20v170')
# t: 18000
# ('20', 'v', '170')
# g:  2.0
# v: 170
# ('t18000', 'g', '20v180')
# t: 18000
# ('20', 'v', '180')
# g:  2.0
# v: 180
# ('t18000', 'g', '20v190')
# t: 18000
# ('20', 'v', '190')
# g:  2.0
# v: 190
# ('t18000', 'g', '20v200')
# t: 18000
# ('20', 'v', '200')
# g:  2.0
# v: 200
# ('t18000', 'g', '20v210')
# t: 18000
# ('20', 'v', '210')
# g:  2.0
# v: 210
# ('t18000', 'g', '20v220')
# t: 18000
# ('20', 'v', '220')
# g:  2.0
# v: 220
# ('t18000', 'g', '20v230')
# t: 18000
# ('20', 'v', '230')
# g:  2.0
# v: 230
# ('t18000', 'g', '20v240')
# t: 18000
# ('20', 'v', '240')
# g:  2.0
# v: 240
# ('t18000', 'g', '20v250')
# t: 18000
# ('20', 'v', '250')
# g:  2.0
# v: 250
# ('t18000', 'g', '20v260')
# t: 18000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# ('t18000', 'g', '20v270')
# t: 18000
# ('20', 'v', '270')
# g:  2.0
# v: 270
# ('t18000', 'g', '20v280')
# t: 18000
# ('20', 'v', '280')
# g:  2.0
# v: 280
# ('t18000', 'g', '20v290')
# t: 18000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# ('t18000', 'g', '20v300')
# t: 18000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# ('t18000', 'g', '20v310')
# t: 18000
# ('20', 'v', '310')
# g:  2.0
# v: 310
# ('t18000', 'g', '20v320')
# t: 18000
# ('20', 'v', '320')
# g:  2.0
# v: 320
# ('t18000', 'g', '20v330')
# t: 18000
# ('20', 'v', '330')
# g:  2.0
# v: 330
# ('t18000', 'g', '20v340')
# t: 18000
# ('20', 'v', '340')
# g:  2.0
# v: 340
# ('t18000', 'g', '20v350')
# t: 18000
# ('20', 'v', '350')
# g:  2.0
# v: 350
# ('t18000', 'g', '20v360')
# t: 18000
# ('20', 'v', '360')
# g:  2.0
# v: 360
# ('t18000', 'g', '20v370')
# t: 18000
# ('20', 'v', '370')
# g:  2.0
# v: 370
# ('t18000', 'g', '20v380')
# t: 18000
# ('20', 'v', '380')
# g:  2.0
# v: 380
# ('t18000', 'g', '20v390')
# t: 18000
# ('20', 'v', '390')
# g:  2.0
# v: 390
# ('t18000', 'g', '20v400')
# t: 18000
# ('20', 'v', '400')
# g:  2.0
# v: 400
# ('t18000', 'g', '25v100')
# t: 18000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# ('t18000', 'g', '25v110')
# t: 18000
# ('25', 'v', '110')
# g:  2.5
# v: 110
# ('t18000', 'g', '25v120')
# t: 18000
# ('25', 'v', '120')
# g:  2.5
# v: 120
# ('t18000', 'g', '25v130')
# t: 18000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# ('t18000', 'g', '25v140')
# t: 18000
# ('25', 'v', '140')
# g:  2.5
# v: 140
# ('t18000', 'g', '25v150')
# t: 18000
# ('25', 'v', '150')
# g:  2.5
# v: 150
# ('t18000', 'g', '25v160')
# t: 18000
# ('25', 'v', '160')
# g:  2.5
# v: 160
# ('t18000', 'g', '25v170')
# t: 18000
# ('25', 'v', '170')
# g:  2.5
# v: 170
# ('t18000', 'g', '25v180')
# t: 18000
# ('25', 'v', '180')
# g:  2.5
# v: 180
# ('t18000', 'g', '25v190')
# t: 18000
# ('25', 'v', '190')
# g:  2.5
# v: 190
# ('t18000', 'g', '25v200')
# t: 18000
# ('25', 'v', '200')
# g:  2.5
# v: 200
# ('t18000', 'g', '25v210')
# t: 18000
# ('25', 'v', '210')
# g:  2.5
# v: 210
# ('t18000', 'g', '25v220')
# t: 18000
# ('25', 'v', '220')
# g:  2.5
# v: 220
# ('t18000', 'g', '25v230')
# t: 18000
# ...
# t: 38000
# ('50', 'v', '260')
# g:  5.0
# v: 260
# ('t38000', 'g', '50v270')
# t: 38000
# ('50', 'v', '270')
# g:  5.0
# v: 270
# ('t38000', 'g', '50v280')
# t: 38000
# ('50', 'v', '280')
# g:  5.0
# v: 280
# ('t38000', 'g', '50v290')
# t: 38000
# ('50', 'v', '290')
# g:  5.0
# v: 290
# ('t38000', 'g', '50v300')
# t: 38000
# ('50', 'v', '300')
# g:  5.0
# v: 300
# ('t38000', 'g', '50v310')
# t: 38000
# ('50', 'v', '310')
# g:  5.0
# v: 310
# ('t38000', 'g', '50v320')
# t: 38000
# ('50', 'v', '320')
# g:  5.0
# v: 320
# ('t38000', 'g', '50v330')
# t: 38000
# ('50', 'v', '330')
# g:  5.0
# v: 330
# ('t38000', 'g', '50v340')
# t: 38000
# ('50', 'v', '340')
# g:  5.0
# v: 340
# ('t38000', 'g', '50v350')
# t: 38000
# ('50', 'v', '350')
# g:  5.0
# v: 350
# ('t38000', 'g', '50v360')
# t: 38000
# ('50', 'v', '360')
# g:  5.0
# v: 360
# ('t38000', 'g', '50v370')
# t: 38000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# ('t38000', 'g', '50v380')
# t: 38000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# ('t38000', 'g', '50v390')
# t: 38000
# ('50', 'v', '390')
# g:  5.0
# v: 390
# ('t38000', 'g', '50v400')
# t: 38000
# ('50', 'v', '400')
# g:  5.0
# v: 400
# ('t39000', 'g', '20v100')
# t: 39000
# ('20', 'v', '100')
# g:  2.0
# v: 100
# ('t39000', 'g', '20v110')
# t: 39000
# ('20', 'v', '110')
# g:  2.0
# v: 110
# ('t39000', 'g', '20v120')
# t: 39000
# ('20', 'v', '120')
# g:  2.0
# v: 120
# ('t39000', 'g', '20v130')
# t: 39000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# ('t39000', 'g', '20v140')
# t: 39000
# ('20', 'v', '140')
# g:  2.0
# v: 140
# ('t39000', 'g', '20v150')
# t: 39000
# ('20', 'v', '150')
# g:  2.0
# v: 150
# ('t39000', 'g', '20v160')
# t: 39000
# ('20', 'v', '160')
# g:  2.0
# v: 160
# ('t39000', 'g', '20v170')
# t: 39000
# ('20', 'v', '170')
# g:  2.0
# v: 170
# ('t39000', 'g', '20v180')
# t: 39000
# ('20', 'v', '180')
# g:  2.0
# v: 180
# ('t39000', 'g', '20v190')
# t: 39000
# ('20', 'v', '190')
# g:  2.0
# v: 190
# ('t39000', 'g', '20v200')
# t: 39000
# ('20', 'v', '200')
# g:  2.0
# v: 200
# ('t39000', 'g', '20v210')
# t: 39000
# ('20', 'v', '210')
# g:  2.0
# v: 210
# ('t39000', 'g', '20v220')
# t: 39000
# ('20', 'v', '220')
# g:  2.0
# v: 220
# ('t39000', 'g', '20v230')
# t: 39000
# ('20', 'v', '230')
# g:  2.0
# v: 230
# ('t39000', 'g', '20v240')
# t: 39000
# ('20', 'v', '240')
# g:  2.0
# v: 240
# ('t39000', 'g', '20v250')
# t: 39000
# ('20', 'v', '250')
# g:  2.0
# v: 250
# ('t39000', 'g', '20v260')
# t: 39000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# ('t39000', 'g', '20v270')
# t: 39000
# ('20', 'v', '270')
# g:  2.0
# v: 270
# ('t39000', 'g', '20v280')
# t: 39000
# ('20', 'v', '280')
# g:  2.0
# v: 280
# ('t39000', 'g', '20v290')
# t: 39000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# ('t39000', 'g', '20v300')
# t: 39000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# ('t39000', 'g', '20v310')
# t: 39000
# ('20', 'v', '310')
# g:  2.0
# v: 310
# ('t39000', 'g', '20v320')
# t: 39000
# ('20', 'v', '320')
# g:  2.0
# v: 320
# ('t39000', 'g', '20v330')
# t: 39000
# ('20', 'v', '330')
# g:  2.0
# v: 330
# ('t39000', 'g', '20v340')
# t: 39000
# ('20', 'v', '340')
# g:  2.0
# v: 340
# ('t39000', 'g', '20v350')
# t: 39000
# ('20', 'v', '350')
# g:  2.0
# v: 350
# ('t39000', 'g', '20v360')
# t: 39000
# ('20', 'v', '360')
# g:  2.0
# v: 360
# ('t39000', 'g', '20v370')
# t: 39000
# ('20', 'v', '370')
# g:  2.0
# v: 370
# ('t39000', 'g', '20v380')
# t: 39000
# ('20', 'v', '380')
# g:  2.0
# v: 380
# ('t39000', 'g', '20v390')
# t: 39000
# ('20', 'v', '390')
# g:  2.0
# v: 390
# ('t39000', 'g', '20v400')
# t: 39000
# ('20', 'v', '400')
# g:  2.0
# v: 400
# ('t39000', 'g', '25v100')
# t: 39000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# ('t39000', 'g', '25v110')
# t: 39000
# ('25', 'v', '110')
# g:  2.5
# v: 110
# ('t39000', 'g', '25v120')
# t: 39000
# ('25', 'v', '120')
# g:  2.5
# v: 120
# ('t39000', 'g', '25v130')
# t: 39000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# ('t39000', 'g', '25v140')
# t: 39000
# ('25', 'v', '140')
# g:  2.5
# v: 140
# ('t39000', 'g', '25v150')
# t: 39000
# ('25', 'v', '150')
# g:  2.5
# v: 150
# ('t39000', 'g', '25v160')
# t: 39000
# ('25', 'v', '160')
# g:  2.5
# v: 160
# ('t39000', 'g', '25v170')
# t: 39000
# ('25', 'v', '170')
# g:  2.5
# v: 170
# ('t39000', 'g', '25v180')
# t: 39000
# ('25', 'v', '180')
# g:  2.5
# v: 180
# ('t39000', 'g', '25v190')
# t: 39000
# ('25', 'v', '190')
# g:  2.5
# v: 190
# ('t39000', 'g', '25v200')
# t: 39000
# ('25', 'v', '200')
# g:  2.5
# v: 200
# ('t39000', 'g', '25v210')
# t: 39000
# ('25', 'v', '210')
# g:  2.5
# v: 210
# ('t39000', 'g', '25v220')
# t: 39000
# ('25', 'v', '220')
# g:  2.5
# v: 220
# ('t39000', 'g', '25v230')
# t: 39000
# ('25', 'v', '230')
# g:  2.5
# v: 230
# ('t39000', 'g', '25v240')
# t: 39000
# ('25', 'v', '240')
# g:  2.5
# v: 240
# ('t39000', 'g', '25v250')
# t: 39000
# ('25', 'v', '250')
# g:  2.5
# v: 250
# ('t39000', 'g', '25v260')
# t: 39000
# ('25', 'v', '260')
# g:  2.5
# v: 260
# ('t39000', 'g', '25v270')
# t: 39000
# ('25', 'v', '270')
# g:  2.5
# v: 270
# ('t39000', 'g', '25v280')
# t: 39000
# ('25', 'v', '280')
# g:  2.5
# v: 280
# ('t39000', 'g', '25v290')
# t: 39000
# ('25', 'v', '290')
# g:  2.5
# v: 290
# ('t39000', 'g', '25v300')
# t: 39000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# ('t39000', 'g', '25v310')
# t: 39000
# ('25', 'v', '310')
# g:  2.5
# v: 310
# ('t39000', 'g', '25v320')
# t: 39000
# ('25', 'v', '320')
# g:  2.5
# v: 320
# ('t39000', 'g', '25v330')
# t: 39000
# ('25', 'v', '330')
# g:  2.5
# v: 330
# ('t39000', 'g', '25v340')
# t: 39000
# ('25', 'v', '340')
# g:  2.5
# v: 340
# ('t39000', 'g', '25v350')
# t: 39000
# ('25', 'v', '350')
# g:  2.5
# v: 350
# ('t39000', 'g', '25v360')
# t: 39000
# ('25', 'v', '360')
# g:  2.5
# v: 360
# ('t39000', 'g', '25v370')
# t: 39000
# ('25', 'v', '370')
# g:  2.5
# v: 370
# ('t39000', 'g', '25v380')
# t: 39000
# ('25', 'v', '380')
# g:  2.5
# v: 380
# ('t39000', 'g', '25v390')
# t: 39000
# ('25', 'v', '390')
# g:  2.5
# v: 390
# ('t39000', 'g', '25v400')
# t: 39000
# ('25', 'v', '400')
# g:  2.5
# v: 400
# ('t39000', 'g', '30v100')
# t: 39000
# ('30', 'v', '100')
# g:  3.0
# v: 100
# ('t39000', 'g', '30v110')
# t: 39000
# ('30', 'v', '110')
# g:  3.0
# v: 110
# ('t39000', 'g', '30v120')
# t: 39000
# ('30', 'v', '120')
# g:  3.0
# v: 120
# ('t39000', 'g', '30v130')
# t: 39000
# ('30', 'v', '130')
# g:  3.0
# v: 130
# ('t39000', 'g', '30v140')
# t: 39000
# ('30', 'v', '140')
# g:  3.0
# v: 140
# ('t39000', 'g', '30v150')
# t: 39000
# ('30', 'v', '150')
# g:  3.0
# v: 150
# ('t39000', 'g', '30v160')
# t: 39000
# ('30', 'v', '160')
# g:  3.0
# v: 160
# ('t39000', 'g', '30v170')
# t: 39000
# ('30', 'v', '170')
# g:  3.0
# v: 170
# ('t39000', 'g', '30v180')
# t: 39000
# ('30', 'v', '180')
# g:  3.0
# v: 180
# ('t39000', 'g', '30v190')
# t: 39000
# ('30', 'v', '190')
# g:  3.0
# v: 190
# ('t39000', 'g', '30v200')
# t: 39000
# ('30', 'v', '200')
# g:  3.0
# v: 200
# ('t39000', 'g', '30v210')
# t: 39000
# ('30', 'v', '210')
# g:  3.0
# v: 210
# ('t39000', 'g', '30v220')
# t: 39000
# ('30', 'v', '220')
# g:  3.0
# v: 220
# ('t39000', 'g', '30v230')
# t: 39000
# ('30', 'v', '230')
# g:  3.0
# v: 230
# ('t39000', 'g', '30v240')
# t: 39000
# ('30', 'v', '240')
# g:  3.0
# v: 240
# ('t39000', 'g', '30v250')
# t: 39000
# ('30', 'v', '250')
# g:  3.0
# v: 250
# ('t39000', 'g', '30v260')
# t: 39000
# ('30', 'v', '260')
# g:  3.0
# v: 260
# ('t39000', 'g', '30v270')
# t: 39000
# ('30', 'v', '270')
# g:  3.0
# v: 270
# ('t39000', 'g', '30v280')
# t: 39000
# ('30', 'v', '280')
# g:  3.0
# v: 280
# ('t39000', 'g', '30v290')
# t: 39000
# ('30', 'v', '290')
# g:  3.0
# v: 290
# ('t39000', 'g', '30v300')
# t: 39000
# ('30', 'v', '300')
# g:  3.0
# v: 300
# ('t39000', 'g', '30v310')
# t: 39000
# ('30', 'v', '310')
# g:  3.0
# v: 310
# ('t39000', 'g', '30v320')
# t: 39000
# ('30', 'v', '320')
# g:  3.0
# v: 320
# ('t39000', 'g', '30v330')
# t: 39000
# ('30', 'v', '330')
# g:  3.0
# v: 330
# ('t39000', 'g', '30v340')
# t: 39000
# ('30', 'v', '340')
# g:  3.0
# v: 340
# ('t39000', 'g', '30v350')
# t: 39000
# ('30', 'v', '350')
# g:  3.0
# v: 350
# ('t39000', 'g', '30v360')
# t: 39000
# ('30', 'v', '360')
# g:  3.0
# v: 360
# ('t39000', 'g', '30v370')
# t: 39000
# ('30', 'v', '370')
# g:  3.0
# v: 370
# ('t39000', 'g', '30v380')
# t: 39000
# ('30', 'v', '380')
# g:  3.0
# v: 380
# ('t39000', 'g', '30v390')
# t: 39000
# ('30', 'v', '390')
# g:  3.0
# v: 390
# ('t39000', 'g', '30v400')
# t: 39000
# ('30', 'v', '400')
# g:  3.0
# v: 400
# ('t39000', 'g', '35v100')
# t: 39000
# ('35', 'v', '100')
# g:  3.5
# v: 100
# ('t39000', 'g', '35v110')
# t: 39000
# ('35', 'v', '110')
# g:  3.5
# v: 110
# ('t39000', 'g', '35v120')
# t: 39000
# ('35', 'v', '120')
# g:  3.5
# v: 120
# ('t39000', 'g', '35v130')
# t: 39000
# ('35', 'v', '130')
# g:  3.5
# v: 130
# ('t39000', 'g', '35v140')
# t: 39000
# ('35', 'v', '140')
# g:  3.5
# v: 140
# ('t39000', 'g', '35v150')
# t: 39000
# ('35', 'v', '150')
# g:  3.5
# v: 150
# ('t39000', 'g', '35v160')
# t: 39000
# ('35', 'v', '160')
# g:  3.5
# v: 160
# ('t39000', 'g', '35v170')
# t: 39000
# ('35', 'v', '170')
# g:  3.5
# v: 170
# ('t39000', 'g', '35v180')
# t: 39000
# ('35', 'v', '180')
# g:  3.5
# v: 180
# ('t39000', 'g', '35v190')
# t: 39000
# ('35', 'v', '190')
# g:  3.5
# v: 190
# ('t39000', 'g', '35v200')
# t: 39000
# ('35', 'v', '200')
# g:  3.5
# v: 200
# ('t39000', 'g', '35v210')
# t: 39000
# ('35', 'v', '210')
# g:  3.5
# v: 210
# ('t39000', 'g', '35v220')
# t: 39000
# ('35', 'v', '220')
# g:  3.5
# v: 220
# ('t39000', 'g', '35v230')
# t: 39000
# ('35', 'v', '230')
# g:  3.5
# v: 230
# ('t39000', 'g', '35v240')
# t: 39000
# ('35', 'v', '240')
# g:  3.5
# v: 240
# ('t39000', 'g', '35v250')
# t: 39000
# ('35', 'v', '250')
# g:  3.5
# v: 250
# ('t39000', 'g', '35v260')
# t: 39000
# ('35', 'v', '260')
# g:  3.5
# v: 260
# ('t39000', 'g', '35v270')
# t: 39000
# ('35', 'v', '270')
# g:  3.5
# v: 270
# ('t39000', 'g', '35v280')
# t: 39000
# ('35', 'v', '280')
# g:  3.5
# v: 280
# ('t39000', 'g', '35v290')
# t: 39000
# ('35', 'v', '290')
# g:  3.5
# v: 290
# ('t39000', 'g', '35v300')
# t: 39000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# ('t39000', 'g', '35v310')
# t: 39000
# ('35', 'v', '310')
# g:  3.5
# v: 310
# ('t39000', 'g', '35v320')
# t: 39000
# ('35', 'v', '320')
# g:  3.5
# v: 320
# ('t39000', 'g', '35v330')
# t: 39000
# ('35', 'v', '330')
# g:  3.5
# v: 330
# ('t39000', 'g', '35v340')
# t: 39000
# ('35', 'v', '340')
# g:  3.5
# v: 340
# ('t39000', 'g', '35v350')
# t: 39000
# ('35', 'v', '350')
# g:  3.5
# v: 350
# ('t39000', 'g', '35v360')
# t: 39000
# ('35', 'v', '360')
# g:  3.5
# v: 360
# ('t39000', 'g', '35v370')
# t: 39000
# ('35', 'v', '370')
# g:  3.5
# v: 370
# ('t39000', 'g', '35v380')
# t: 39000
# ('35', 'v', '380')
# g:  3.5
# v: 380
# ('t39000', 'g', '35v390')
# t: 39000
# ('35', 'v', '390')
# g:  3.5
# v: 390
# ('t39000', 'g', '35v400')
# t: 39000
# ('35', 'v', '400')
# g:  3.5
# v: 400
# ('t39000', 'g', '40v100')
# t: 39000
# ('40', 'v', '100')
# g:  4.0
# v: 100
# ('t39000', 'g', '40v110')
# t: 39000
# ('40', 'v', '110')
# g:  4.0
# v: 110
# ('t39000', 'g', '40v120')
# t: 39000
# ('40', 'v', '120')
# g:  4.0
# v: 120
# ('t39000', 'g', '40v130')
# t: 39000
# ('40', 'v', '130')
# g:  4.0
# v: 130
# ('t39000', 'g', '40v140')
# t: 39000
# ('40', 'v', '140')
# g:  4.0
# v: 140
# ('t39000', 'g', '40v150')
# t: 39000
# ('40', 'v', '150')
# g:  4.0
# v: 150
# ('t39000', 'g', '40v160')
# t: 39000
# ('40', 'v', '160')
# g:  4.0
# v: 160
# ('t39000', 'g', '40v170')
# t: 39000
# ('40', 'v', '170')
# g:  4.0
# v: 170
# ('t39000', 'g', '40v180')
# t: 39000
# ('40', 'v', '180')
# g:  4.0
# v: 180
# ('t39000', 'g', '40v190')
# t: 39000
# ('40', 'v', '190')
# g:  4.0
# v: 190
# ('t39000', 'g', '40v200')
# t: 39000
# ('40', 'v', '200')
# g:  4.0
# v: 200
# ('t39000', 'g', '40v210')
# t: 39000
# ('40', 'v', '210')
# g:  4.0
# v: 210
# ('t39000', 'g', '40v220')
# t: 39000
# ('40', 'v', '220')
# g:  4.0
# v: 220
# ('t39000', 'g', '40v230')
# t: 39000
# ('40', 'v', '230')
# g:  4.0
# v: 230
# ('t39000', 'g', '40v240')
# t: 39000
# ('40', 'v', '240')
# g:  4.0
# v: 240
# ('t39000', 'g', '40v250')
# t: 39000
# ('40', 'v', '250')
# g:  4.0
# v: 250
# ('t39000', 'g', '40v260')
# t: 39000
# ('40', 'v', '260')
# g:  4.0
# v: 260
# ('t39000', 'g', '40v270')
# t: 39000
# ('40', 'v', '270')
# g:  4.0
# v: 270
# ('t39000', 'g', '40v280')
# t: 39000
# ('40', 'v', '280')
# g:  4.0
# v: 280
# ('t39000', 'g', '40v290')
# t: 39000
# ('40', 'v', '290')
# g:  4.0
# v: 290
# ('t39000', 'g', '40v300')
# t: 39000
# ('40', 'v', '300')
# g:  4.0
# v: 300
# ('t39000', 'g', '40v310')
# t: 39000
# ('40', 'v', '310')
# g:  4.0
# v: 310
# ('t39000', 'g', '40v320')
# t: 39000
# ('40', 'v', '320')
# g:  4.0
# v: 320
# ('t39000', 'g', '40v330')
# t: 39000
# ('40', 'v', '330')
# g:  4.0
# v: 330
# ('t39000', 'g', '40v340')
# t: 39000
# ('40', 'v', '340')
# g:  4.0
# v: 340
# ('t39000', 'g', '40v350')
# t: 39000
# ('40', 'v', '350')
# g:  4.0
# v: 350
# ('t39000', 'g', '40v360')
# t: 39000
# ('40', 'v', '360')
# g:  4.0
# v: 360
# ('t39000', 'g', '40v370')
# t: 39000
# ('40', 'v', '370')
# g:  4.0
# v: 370
# ('t39000', 'g', '40v380')
# t: 39000
# ('40', 'v', '380')
# g:  4.0
# v: 380
# ('t39000', 'g', '40v390')
# t: 39000
# ('40', 'v', '390')
# g:  4.0
# v: 390
# ('t39000', 'g', '40v400')
# t: 39000
# ('40', 'v', '400')
# g:  4.0
# v: 400
# ('t39000', 'g', '45v100')
# t: 39000
# ('45', 'v', '100')
# g:  4.5
# v: 100
# ('t39000', 'g', '45v110')
# t: 39000
# ('45', 'v', '110')
# g:  4.5
# v: 110
# ('t39000', 'g', '45v120')
# t: 39000
# ('45', 'v', '120')
# g:  4.5
# v: 120
# ('t39000', 'g', '45v130')
# t: 39000
# ('45', 'v', '130')
# g:  4.5
# v: 130
# ('t39000', 'g', '45v140')
# t: 39000
# ('45', 'v', '140')
# g:  4.5
# v: 140
# ('t39000', 'g', '45v150')
# t: 39000
# ('45', 'v', '150')
# g:  4.5
# v: 150
# ('t39000', 'g', '45v160')
# t: 39000
# ('45', 'v', '160')
# g:  4.5
# v: 160
# ('t39000', 'g', '45v170')
# t: 39000
# ('45', 'v', '170')
# g:  4.5
# v: 170
# ('t39000', 'g', '45v180')
# t: 39000
# ('45', 'v', '180')
# g:  4.5
# v: 180
# ('t39000', 'g', '45v190')
# t: 39000
# ('45', 'v', '190')
# g:  4.5
# v: 190
# ('t39000', 'g', '45v200')
# t: 39000
# ('45', 'v', '200')
# g:  4.5
# v: 200
# ('t39000', 'g', '45v210')
# t: 39000
# ('45', 'v', '210')
# g:  4.5
# v: 210
# ('t39000', 'g', '45v220')
# t: 39000
# ('45', 'v', '220')
# g:  4.5
# v: 220
# ('t39000', 'g', '45v230')
# t: 39000
# ('45', 'v', '230')
# g:  4.5
# v: 230
# ('t39000', 'g', '45v240')
# t: 39000
# ('45', 'v', '240')
# g:  4.5
# v: 240
# ('t39000', 'g', '45v250')
# t: 39000
# ('45', 'v', '250')
# g:  4.5
# v: 250
# ('t39000', 'g', '45v260')
# t: 39000
# ('45', 'v', '260')
# g:  4.5
# v: 260
# ('t39000', 'g', '45v270')
# t: 39000
# ('45', 'v', '270')
# g:  4.5
# v: 270
# ('t39000', 'g', '45v280')
# t: 39000
# ('45', 'v', '280')
# g:  4.5
# v: 280
# ('t39000', 'g', '45v290')
# t: 39000
# ('45', 'v', '290')
# g:  4.5
# v: 290
# ('t39000', 'g', '45v300')
# t: 39000
# ('45', 'v', '300')
# g:  4.5
# v: 300
# ('t39000', 'g', '45v310')
# t: 39000
# ('45', 'v', '310')
# g:  4.5
# v: 310
# ('t39000', 'g', '45v320')
# t: 39000
# ('45', 'v', '320')
# g:  4.5
# v: 320
# ('t39000', 'g', '45v330')
# t: 39000
# ('45', 'v', '330')
# g:  4.5
# v: 330
# ('t39000', 'g', '45v340')
# t: 39000
# ('45', 'v', '340')
# g:  4.5
# v: 340
# ('t39000', 'g', '45v350')
# t: 39000
# ('45', 'v', '350')
# g:  4.5
# v: 350
# ('t39000', 'g', '45v360')
# t: 39000
# ('45', 'v', '360')
# g:  4.5
# v: 360
# ('t39000', 'g', '45v370')
# t: 39000
# ('45', 'v', '370')
# g:  4.5
# v: 370
# ('t39000', 'g', '45v380')
# t: 39000
# ('45', 'v', '380')
# g:  4.5
# v: 380
# ('t39000', 'g', '45v390')
# t: 39000
# ('45', 'v', '390')
# g:  4.5
# v: 390
# ('t39000', 'g', '45v400')
# t: 39000
# ('45', 'v', '400')
# g:  4.5
# v: 400
# ('t39000', 'g', '50v100')
# t: 39000
# ('50', 'v', '100')
# g:  5.0
# v: 100
# ('t39000', 'g', '50v110')
# t: 39000
# ('50', 'v', '110')
# g:  5.0
# v: 110
# ('t39000', 'g', '50v120')
# t: 39000
# ('50', 'v', '120')
# g:  5.0
# v: 120
# ('t39000', 'g', '50v130')
# t: 39000
# ('50', 'v', '130')
# g:  5.0
# v: 130
# ('t39000', 'g', '50v140')
# t: 39000
# ('50', 'v', '140')
# g:  5.0
# v: 140
# ('t39000', 'g', '50v150')
# t: 39000
# ('50', 'v', '150')
# g:  5.0
# v: 150
# ('t39000', 'g', '50v160')
# t: 39000
# ('50', 'v', '160')
# g:  5.0
# v: 160
# ('t39000', 'g', '50v170')
# t: 39000
# ('50', 'v', '170')
# g:  5.0
# v: 170
# ('t39000', 'g', '50v180')
# t: 39000
# ('50', 'v', '180')
# g:  5.0
# v: 180
# ('t39000', 'g', '50v190')
# t: 39000
# ('50', 'v', '190')
# g:  5.0
# v: 190
# ('t39000', 'g', '50v200')
# t: 39000
# ('50', 'v', '200')
# g:  5.0
# v: 200
# ('t39000', 'g', '50v210')
# t: 39000
# ('50', 'v', '210')
# g:  5.0
# v: 210
# ('t39000', 'g', '50v220')
# t: 39000
# ('50', 'v', '220')
# g:  5.0
# v: 220
# ('t39000', 'g', '50v230')
# t: 39000
# ('50', 'v', '230')
# g:  5.0
# v: 230
# ('t39000', 'g', '50v240')
# t: 39000
# ('50', 'v', '240')
# g:  5.0
# v: 240
# ('t39000', 'g', '50v250')
# t: 39000
# ('50', 'v', '250')
# g:  5.0
# v: 250
# ('t39000', 'g', '50v260')
# t: 39000
# ('50', 'v', '260')
# g:  5.0
# v: 260
# ('t39000', 'g', '50v270')
# t: 39000
# ('50', 'v', '270')
# g:  5.0
# v: 270
# ('t39000', 'g', '50v280')
# t: 39000
# ('50', 'v', '280')
# g:  5.0
# v: 280
# ('t39000', 'g', '50v290')
# t: 39000
# ('50', 'v', '290')
# g:  5.0
# v: 290
# ('t39000', 'g', '50v300')
# t: 39000
# ('50', 'v', '300')
# g:  5.0
# v: 300
# ('t39000', 'g', '50v310')
# t: 39000
# ('50', 'v', '310')
# g:  5.0
# v: 310
# ('t39000', 'g', '50v320')
# t: 39000
# ('50', 'v', '320')
# g:  5.0
# v: 320
# ('t39000', 'g', '50v330')
# t: 39000
# ('50', 'v', '330')
# g:  5.0
# v: 330
# ('t39000', 'g', '50v340')
# t: 39000
# ('50', 'v', '340')
# g:  5.0
# v: 340
# ('t39000', 'g', '50v350')
# t: 39000
# ('50', 'v', '350')
# g:  5.0
# v: 350
# ('t39000', 'g', '50v360')
# t: 39000
# ('50', 'v', '360')
# g:  5.0
# v: 360
# ('t39000', 'g', '50v370')
# t: 39000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# ('t39000', 'g', '50v380')
# t: 39000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# ('t39000', 'g', '50v390')
# t: 39000
# ('50', 'v', '390')
# g:  5.0
# v: 390
# ('t39000', 'g', '50v400')
# t: 39000
# ('50', 'v', '400')
# g:  5.0
# v: 400

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix


# ¿Será necesario normalizar X?
########
scaler = StandardScaler()
scaler.fit(X)
#X_s = scaler.transform(X)
X = scaler.transform(X)

# Normalización de los labels
scaler2 = StandardScaler()
scaler2.fit(y)
y_s = scaler2.transform(y)

# %% [markdown]
# ## Training, testing and validation sets

# %%
def train_val_test_split(X, y, train_size, val_size, test_size, random_state = 1):
    if train_size + val_size + test_size != 1.0:
        print("Incorrect sizes!")
        return None
    
    X_tmp, X_test, y_tmp, y_test = train_test_split(X, y, test_size = test_size, random_state=random_state)
    X_train, X_val, y_train, y_val = train_test_split(X_tmp, y_tmp, test_size = val_size/(test_size + train_size), random_state=random_state)
    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
X_train, X_val, X_test, y_train, y_val, y_test = train_val_test_split(X, y_s, .8, .1, .1)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (4339, 201) (4339, 3)
# (543, 201) (543, 3)
# (543, 201) (543, 3)

# %% [markdown]
# # Convolutional neural network

# %%
# about activation functions: https://datascience.stackexchange.com/questions/47751/what-activation-function-should-i-use-for-a-specific-regression-problem

# %%
# https://colab.research.google.com/drive/1zjh0tUPYJYgJJunpLC9fW5uf--O0LKeZ?usp=sharing#scrollTo=ud_tq1A0Ffvl

time_steps = X.shape[1]
input_dimension = 1

# %%
sample_size = X_train.shape[0]
X_train_reshaped = X_train.reshape((sample_size, time_steps, input_dimension))
sample_size = X_val.shape[0]
X_val_reshaped = X_val.reshape((sample_size, time_steps, input_dimension))
sample_size = X_test.shape[0]
X_test_reshaped = X_test.reshape((sample_size, time_steps, input_dimension))

# %%
print(X_train_reshaped.shape)
print(X_val_reshaped.shape)
print(X_test_reshaped.shape)
# Out:
# (4339, 201, 1)
# (543, 201, 1)
# (543, 201, 1)

# %% [markdown]
# # Histograms
# *****

# %%
def histograms_params(train, test, val, bins, labels, title=None):
    plt.figure()
    plt.hist(train, bins='auto', label=labels[0])
    if val is not None:
        plt.hist(val, bins='auto', label=labels[1])
    if test is not None:
        plt.hist(test, bins='auto', label=labels[2], alpha=0.3)
    
    if title is not None:
        plt.title(title)
    plt.legend(loc="best")
    plt.show()
    

import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
histograms_params(y_train[:,0], y_val[:,0], y_test[:,0], 0, ["train", "test", "val"])
histograms_params(y_train[:,1], y_val[:,1], y_test[:,1], 0, ["train", "test", "val"], "Log g")
histograms_params(y_train[:,2], y_val[:,2], y_test[:,2], 0, ["train", "test", "val"], "v rot")

# %%
import tensorflow as tf
import keras

# %% [markdown]
# ### Optimizar los parámetros de esta red
# ***
# - Puede cambiar la arquitectura, agregando o quitando capas, modificando las funciones de activación, cambiando la función de pérdida, etc.

# %%
def build_conv1D_model():
    n_timesteps = X_train_reshaped.shape[1] #210
    n_features  = X_train_reshaped.shape[2] #1 
    model = keras.Sequential(name="model_conv1D")
    model.add(keras.layers.Input(shape=(n_timesteps,n_features)))
    model.add(keras.layers.Conv1D(filters=16, kernel_size=3, activation='selu', name="Conv1D_1"))
    model.add(keras.layers.Conv1D(filters=16, kernel_size=3, activation='selu', name="Conv1D_2"))
    model.add(keras.layers.Conv1D(filters=16, kernel_size=3, activation='selu', name="Conv1D_3"))
    model.add(keras.layers.Conv1D(filters=16, kernel_size=3, activation='selu', name="Conv1D_4"))
    tf.keras.layers.BatchNormalization()
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(32, activation= "selu", name="Dense_1"))
    model.add(keras.layers.Dense(3, activation = "selu", name="Dense_4"))

    optimizer = tf.keras.optimizers.RMSprop(0.001)

    l = tf.keras.losses.LogCosh()
    
    model.compile(loss='mse',optimizer=optimizer,metrics=['mse'])
    return model

model_conv1D = build_conv1D_model()
model_conv1D.summary()#
# Out:
# Model: "model_conv1D"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1D_1 (Conv1D)           (None, 199, 16)           64
#
#  Conv1D_2 (Conv1D)           (None, 197, 16)           784
#
#  Conv1D_3 (Conv1D)           (None, 195, 16)           784
#
#  Conv1D_4 (Conv1D)           (None, 193, 16)           784
#
#  flatten_2 (Flatten)         (None, 3088)              0
#
#  Dense_1 (Dense)             (None, 32)                98848
#
#  Dense_4 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 101,363
# Trainable params: 101,363
# Non-trainable params: 0
# _________________________________________________________________

# %%
ep = 50
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', 
                                                patience=5)
history = model_conv1D.fit(X_train_reshaped, y_train, epochs=ep,
                    validation_data = (X_val_reshaped, y_val), 
                           verbose=1, callbacks=[callback])
# Out:
# Epoch 1/50
# 136/136 [==============================] - 2s 11ms/step - loss: 0.8556 - mse: 0.8556 - val_loss: 0.1725 - val_mse: 0.1725
# Epoch 2/50
# 136/136 [==============================] - 1s 9ms/step - loss: 0.3605 - mse: 0.3605 - val_loss: 0.1642 - val_mse: 0.1642
# Epoch 3/50
# 136/136 [==============================] - 1s 9ms/step - loss: 0.2552 - mse: 0.2552 - val_loss: 0.1175 - val_mse: 0.1175
# Epoch 4/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.1988 - mse: 0.1988 - val_loss: 0.1298 - val_mse: 0.1298
# Epoch 5/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.1570 - mse: 0.1570 - val_loss: 0.1382 - val_mse: 0.1382
# Epoch 6/50
# 136/136 [==============================] - 1s 9ms/step - loss: 0.1399 - mse: 0.1399 - val_loss: 0.2075 - val_mse: 0.2075
# Epoch 7/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.1318 - mse: 0.1318 - val_loss: 0.1578 - val_mse: 0.1578
# Epoch 8/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.1192 - mse: 0.1192 - val_loss: 0.0957 - val_mse: 0.0957
# Epoch 9/50
# 136/136 [==============================] - 1s 9ms/step - loss: 0.1083 - mse: 0.1083 - val_loss: 0.1053 - val_mse: 0.1053
# Epoch 10/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.1026 - mse: 0.1026 - val_loss: 0.1229 - val_mse: 0.1229
# Epoch 11/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0940 - mse: 0.0940 - val_loss: 0.1011 - val_mse: 0.1011
# Epoch 12/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0915 - mse: 0.0915 - val_loss: 0.1631 - val_mse: 0.1631
# Epoch 13/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0863 - mse: 0.0863 - val_loss: 0.0941 - val_mse: 0.0941
# Epoch 14/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0838 - mse: 0.0838 - val_loss: 0.0938 - val_mse: 0.0938
# Epoch 15/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0813 - mse: 0.0813 - val_loss: 0.0830 - val_mse: 0.0830
# Epoch 16/50
# 136/136 [==============================] - 1s 11ms/step - loss: 0.0794 - mse: 0.0794 - val_loss: 0.0864 - val_mse: 0.0864
# Epoch 17/50
# 136/136 [==============================] - 1s 11ms/step - loss: 0.0772 - mse: 0.0772 - val_loss: 0.0813 - val_mse: 0.0813
# Epoch 18/50
# 136/136 [==============================] - 1s 11ms/step - loss: 0.0754 - mse: 0.0754 - val_loss: 0.0907 - val_mse: 0.0907
# Epoch 19/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0732 - mse: 0.0732 - val_loss: 0.0826 - val_mse: 0.0826
# Epoch 20/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0720 - mse: 0.0720 - val_loss: 0.0737 - val_mse: 0.0737
# Epoch 21/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0697 - mse: 0.0697 - val_loss: 0.0743 - val_mse: 0.0743
# Epoch 22/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0666 - mse: 0.0666 - val_loss: 0.0681 - val_mse: 0.0681
# Epoch 23/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0663 - mse: 0.0663 - val_loss: 0.0659 - val_mse: 0.0659
# Epoch 24/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0647 - mse: 0.0647 - val_loss: 0.0667 - val_mse: 0.0667
# Epoch 25/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0614 - val_mse: 0.0614
# Epoch 26/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0739 - val_mse: 0.0739
# Epoch 27/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0630 - val_mse: 0.0630
# Epoch 28/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0615 - mse: 0.0615 - val_loss: 0.0831 - val_mse: 0.0831
# Epoch 29/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0634 - val_mse: 0.0634
# Epoch 30/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0581 - mse: 0.0581 - val_loss: 0.0641 - val_mse: 0.0641
# Epoch 31/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0580 - mse: 0.0580 - val_loss: 0.0680 - val_mse: 0.0680
# Epoch 32/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0558 - mse: 0.0558 - val_loss: 0.0731 - val_mse: 0.0731
# Epoch 33/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0573 - mse: 0.0573 - val_loss: 0.0537 - val_mse: 0.0537
# Epoch 34/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0557 - mse: 0.0557 - val_loss: 0.0573 - val_mse: 0.0573
# Epoch 35/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0556 - mse: 0.0556 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 36/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0556 - mse: 0.0556 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 37/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0541 - mse: 0.0541 - val_loss: 0.0637 - val_mse: 0.0637
# Epoch 38/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0536 - mse: 0.0536 - val_loss: 0.0544 - val_mse: 0.0544
# Epoch 39/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0546 - mse: 0.0546 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 40/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0526 - mse: 0.0526 - val_loss: 0.0923 - val_mse: 0.0923
# Epoch 41/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0535 - mse: 0.0535 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 42/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0529 - mse: 0.0529 - val_loss: 0.0530 - val_mse: 0.0530
# Epoch 43/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0515 - mse: 0.0515 - val_loss: 0.0651 - val_mse: 0.0651
# Epoch 44/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0516 - mse: 0.0516 - val_loss: 0.0732 - val_mse: 0.0732
# Epoch 45/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0519 - mse: 0.0519 - val_loss: 0.0796 - val_mse: 0.0796
# Epoch 46/50
# 136/136 [==============================] - 1s 11ms/step - loss: 0.0506 - mse: 0.0506 - val_loss: 0.0537 - val_mse: 0.0537
# Epoch 47/50
# 136/136 [==============================] - 1s 11ms/step - loss: 0.0511 - mse: 0.0511 - val_loss: 0.0530 - val_mse: 0.0530
# Epoch 48/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0507 - mse: 0.0507 - val_loss: 0.0574 - val_mse: 0.0574
# Epoch 49/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0500 - mse: 0.0500 - val_loss: 0.0541 - val_mse: 0.0541
# Epoch 50/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0498 - mse: 0.0498 - val_loss: 0.0495 - val_mse: 0.0495

# %%
[loss, mae] = model_conv1D.evaluate(X_test_reshaped, y_test, verbose=0)
print("Testing set Mean Abs Error: {:7.2f}".format(mae * 1000))

pred =model_conv1D.predict(X_test_reshaped)

y_pred_inv = scaler2.inverse_transform(y)
x_pred_inv = scaler.inverse_transform(X)


train_loss = history.history['loss']


val_loss = history.history['val_loss']


def plot_train_val(A, B, n, xlabel, ylabel, title):
    plt.figure(1, figsize=(10, 6))
    plt.plot(range(n),A)
    plt.plot(range(n),B)
    plt.ylabel(xlabel)
    plt.xlabel(ylabel)
    plt.title(title)
    plt.grid(True)
    plt.legend(['Training', 'Validation'])
    plt.show()


plot_train_val(train_loss, val_loss, ep, 'Loss', 'Number of epochs', 'Training loss vs Validation loss')
# Out:
# Testing set Mean Abs Error:   52.71
# 17/17 [==============================] - 0s 5ms/step

# %%
from sklearn.metrics import mean_absolute_error

# %%
a = scaler2.inverse_transform(pred)
print(a[:,0].shape)


b = scaler2.inverse_transform(y_test)
print(b[:,0].shape)

plt.figure()
plt.hist(a[:,0], label="pred")
plt.hist(b[:,0], label="test")

plt.legend(loc="best")
plt.show()
# Out:
# (543,)
# (543,)

# %%
pred[:,0].shape
# Out:
# (543,)

# %%
plt.figure()
plt.hist(a[:,1], label="pred")
plt.hist(b[:,1], label="test")

plt.legend(loc="best")
plt.show()

# %%
plt.figure()
plt.hist(a[:,2], label="pred")
plt.hist(b[:,2], label="test")

plt.legend(loc="best")
plt.show()

# %%
plt.figure()
plt.hist(pred[:,0], label="pred")
plt.hist(y_test[:,0], label="test")

plt.legend(loc="best")
plt.show()

# %%
plt.figure()
plt.hist(pred[:,1], label="pred")
plt.hist(y_test[:,1], label="test")

plt.legend(loc="best")
plt.show()

# %%
plt.figure()
plt.hist(y_test[:,2], label="test")
plt.hist(pred[:,2], label="pred")
plt.legend(loc="best")
plt.show()

# %%
mean_absolute_error(a, b)
# Out:
# 211.5161893204577

# %%
e_teff = abs(y_test[:,0] - pred[:,0])
e_logg = abs(y_test[:,1] - pred[:,1])
e_vrot = abs(y_test[:,2] - pred[:,2])

# %%
plt.figure()
plt.hist(e_teff)
plt.show()

# %%
plt.figure()
plt.hist(e_logg)
plt.show()

# %%
plt.figure()
plt.hist(e_vrot)
plt.show()

# %% [markdown]
# # BeSoS lines

# %%
df = pd.read_csv("Besos/HD35165_2014-03-20_23-53-54_final_corr.txt", sep="\t", header=None)

m1 = df[0] >= 4460
m2 = df[0] <= 4480

df2 = df[m1][m2]

df2
# Out:
# C:\Users\JEANBI~1\AppData\Local\Temp/ipykernel_16264/3139265490.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df[m1][m2]
#                 0         1
# 2366  4460.054469  0.993731
# 2367  4460.143841  0.938574
# 2368  4460.233212  0.941068
# 2369  4460.322584  1.044194
# 2370  4460.411956  1.082456
# ...           ...       ...
# 2585  4479.626871  0.973056
# 2586  4479.716243  0.928464
# 2587  4479.805615  0.998607
# 2588  4479.894986  1.017380
# 2589  4479.984358  0.984894
#
# [224 rows x 2 columns]

# %%
plt.figure(figsize=(8,6))
plt.plot(df2[0], df2[1], label="Línea observada")
#plt.plot(df4[0], df4[1], label="Modelo")
plt.grid()
plt.legend(loc="best")
plt.show()

# %%
n = 201  # for 2 random indices
index = np.random.choice(df2[0].shape[0], n, replace=False)

# %%
index.sort()

# %%
obs_waves = df2[0].values[index]

obs_flux = df2[1].values[index]

# %%
obs_flux.shape
# Out:
# (201,)

# %%
plt.figure(figsize=(8,6))
plt.plot(obs_waves, obs_flux ,label="Línea observada")
plt.legend(loc="best")
plt.show()

# %%
#obs_x_reshaped = x_obs_inv.reshape((1, time_steps, input_dimension))
#obs_x_reshaped = obs_x.reshape((1, time_steps, input_dimension))

obs_flux_reshaped = obs_flux.reshape((1, time_steps, input_dimension))

# %%
pred_obs =model_conv1D.predict(obs_flux_reshaped)
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
# Acá los resultados es con los datos normalizados
print("t_eff:", pred_obs[0][0])
print("log g:", pred_obs[0][1])
print("v_rot:", pred_obs[0][2])
# Out:
# t_eff: 0.1980814
# log g: -0.74665546
# v_rot: 0.029261665

# %% [markdown]
# ## "Desnomralización de la predicción"

# %%
pred_obs_inv = scaler2.inverse_transform(pred_obs)

# %%
pred_obs_inv
# Out:
# array([[2.8428385e+04, 2.7533445e+00, 2.5261725e+02]], dtype=float32)

# %%
print("t_eff:", pred_obs_inv[0][0])
print("log g:", pred_obs_inv[0][1])
print("v_rot:", pred_obs_inv[0][2])

#print(pred_obs_inv[0,0])
#print(pred_obs_inv[0,1])
#print(pred_obs_inv[0,2])
# Out:
# t_eff: 28428.385
# log g: 2.7533445
# v_rot: 252.61725
